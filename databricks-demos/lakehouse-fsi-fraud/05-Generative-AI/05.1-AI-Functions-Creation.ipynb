# %% [markdown]
# # 🔍 Gen AI-Powered Fraud Detection in Modern Banking
# Banks today face unprecedented fraud risks as criminals use advanced digital tactics to exploit vulnerabilities in online banking. Manual reviews are no longer enough-they’re slow, inconsistent, and often miss complex fraud schemes. As fraudsters leverage technology to scale their attacks, banks must adopt AI-powered solutions that analyze massive data in real time, quickly detect suspicious activity, and reduce false positives. Modern fraud detection now requires the speed, accuracy, and adaptability that only GenAI and machine learning can deliver.
#
#
# <div style="background: #f7f7f7; border-left: 5px solid #ff5f46; padding: 20px; margin: 20px 0; font-size: 18px;">
#   "Fraud scams and bank fraud schemes resulted in <b>$485.6 billion</b> in losses globally last year, with criminals using advanced techniques to evade traditional controls." -
#   <a href="https://www.nasdaq.com/global-financial-crime-report" target="_blank">Nasdaq 2024 Global Financial Crime Report</a>
# </div>
#
# <div style="background: #f7f7f7; border-left: 5px solid green; padding: 20px; margin: 20px 0; font-size: 18px;">
#   "Studies have shown that AI-driven fraud detection can reduce false positives by up to <b>90%</b> compared to traditional methods." -
#   <a href="https://quantumzeitgeist.com/ai-driven-fraud-detection-in-banking-and-financial-services/" target="_blank">Quantum Zeitgeist: AI-driven Fraud Detection In Banking</a>
# </div>
#
# <img src="https://raw.githubusercontent.com/databricks-demos/dbdemos-resources/refs/heads/main/images/liza.png" style="width: 100px; vertical-align: middle; margin-right: 10px; float: left;" />
# <br>
# Liza, a Data Engineer, is using Databricks and generative AI to modernize fraud detection. Her workflow:
#
# <div style="background: #e0f7fa; border-left: 5px solid #00796b; padding-left: 10px; margin: 0 0; margin-left: 120px">
#   <ol style="text-align: left;">
#     <li>Fetch customer details for flagged transactions with AI functions</li>
#     <li>Generate structured fraud reports using generative AI</li>
#     <li>Log all AI functions and outputs in Unity Catalog for compliance</li>
#     <li>Apply these AI functions in batch to analyze all potentially fraudulent transactions</li>
#   </ol>
# </div>
#
# This demo shows how banks can use Databricks and AI to automate fraud detection, improve accuracy, and streamline compliance.
#
# <!-- Collect usage data (view). Remove it to disable collection or disable tracker during installation. View README for more details.  -->
# <img width="1px" src="https://ppxrzfxige.execute-api.us-west-2.amazonaws.com/v1/analytics?category=lakehouse&org_id=2162748966026566&notebook=%2F05-Generative-AI%2F05.1-AI-Functions-Creation&demo_name=lakehouse-fsi-fraud&event=VIEW&path=%2F_dbdemos%2Flakehouse%2Flakehouse-fsi-fraud%2F05-Generative-AI%2F05.1-AI-Functions-Creation&version=1">

# %% [markdown]
# ## The Demo: Automate Suspicious Transaction Fraud Reports with Databricks GenAI
#
# Databricks Generative AI is transforming banking fraud detection by enabling organizations to automate manual workflows, quickly identify suspicious activity, and unlock insights from vast amounts of transaction data. Where traditional fraud review can be slow and resource-intensive, Databricks empowers banks to act faster and more accurately.
#
# In this demo, we showcase a practical use case for Databricks to improve fraud management in modern banking. We will create an AI agent using the following functions, defined in the subsequent cells:
#
# 1. **Customer Information Retriever**: This function allows our GenAI agent to fetch detailed customer information for any given transaction, pulling structured and unstructured data from our Databricks Intelligence Platform.
#
# 2. **Fraud Report Generator**: Using generative AI models, this function creates clear, structured fraud reports for each suspicious transaction, highlighting risk factors, behavioral anomalies, and relevant customer context for further review.
#
# Finally, we will demonstrate how these functions can be applied in batch to analyze all potentially fraudulent transactions. By automating fraud report generation and enabling real-time access to enriched data, banks can improve operational efficiency, accelerate investigations, and enhance compliance.
#
# By leveraging Generative AI, banks can move beyond manual processes to **streamline workflows, reduce costs, and significantly strengthen fraud detection capabilities**.

# %%
# %run ../_resources/00-setup $reset_all_data=false
# Out:
# USE CATALOG `main__build`
# using catalog.database `main__build`.`dbdemos_fsi_fraud_detection`

# %% [markdown]
# ## 📊 Function 1: Get Customer Details
#
# <div style="display: flex; align-items: center; gap: 15px;"> <img src="https://raw.githubusercontent.com/databricks-demos/dbdemos-resources/refs/heads/main/images/liza.png" style="width: 100px; border-radius: 10px;" /> <div> Liza's first step in automating fraud detection is to retrieve all relevant information for a given customer or transaction.<br> This function, <code>get_customer_details</code>, takes in a customer or transaction ID and returns the necessary data to generate a comprehensive fraud report.<br> The retrieved data includes customer profile information, account activity, transaction history, device and location metadata, and any related documents-providing the foundation for accurate and efficient fraud analysis. </div> </div>
#
# ### 🛠️ Next Step
# In the following section, we define the <code>get_customer_details</code> function, which retrieves structured and unstructured data from the Databricks Lakehouse to enable automated fraud report generation.

# %%
# %sql
DROP FUNCTION IF EXISTS get_customer_details;

CREATE OR REPLACE FUNCTION get_customer_details (
  tran_id STRING COMMENT 'Transaction ID of the customer to be searched'
) 
RETURNS TABLE(
  id STRING, 
  is_fraud BOOLEAN, 
  amount DOUBLE, 
  customer_id STRING, 
  nameDest STRING,
  nameOrig STRING, 
  type STRING, 
  firstname STRING, 
  lastname STRING, 
  email STRING, 
  address STRING, 
  country STRING,
  creation_date STRING, 
  age_group DOUBLE, 
  countryOrig_name STRING,
  countryDest_name STRING
)
COMMENT "This function returns the customer details for a given Transaction ID, along with their transaction details" 
RETURN (
  SELECT
    id, 
    is_fraud, 
    amount, 
    customer_id,  
    nameDest, 
    nameOrig, 
    type, 
    firstname, 
    lastname, 
    email, 
    address, 
    country, 
    creation_date, 
    age_group,
    countryOrig_name, 
    countryDest_name
  FROM 
    gold_transactions
  WHERE
    id = tran_id
)

# %% [markdown]
# ### Example:
#
# Let's ensure that our new tool works. Here we look up a transaction that our AI system (_Section 4 of this demo_) knows is fraudulent:

# %%
# %sql
SELECT * FROM get_customer_details(
    '001df0ff-a9a6-4b94-a548-bfb6d5393698'
) AS prediction
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>is_fraud</th><th>amount</th><th>customer_id</th><th>nameDest</th><th>nameOrig</th><th>type</th><th>firstname</th><th>lastname</th><th>email</th><th>address</th><th>country</th><th>creation_date</th><th>age_group</th><th>countryOrig_name</th><th>countryDest_name</th></tr></thead><tbody><tr><td>001df0ff-a9a6-4b94-a548-bfb6d5393698</td><td>true</td><td>400000.0</td><td>80a60ee7-a482-4e69-aa8f-2914f051f5b5</td><td>CC0290993355</td><td>C0047984490</td><td>TRANSFER</td><td>Angela</td><td>Tran</td><td>eburch@smith.com</td><td>282 Amanda Road Apt. 209
# Matthewview, GU 81248</td><td>GRC</td><td>11-05-2021 00:00:00</td><td>6.0</td><td>France</td><td>Nigeria</td></tr></tbody></table></div>

# %% [markdown]
# ### Example:
#
# And now, let's look at a transaction that we know is not fraudulent!

# %%
# %sql
SELECT * FROM get_customer_details(
    '3d1dd327-0120-495e-bb37-34008d7587a9'
) AS prediction
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>is_fraud</th><th>amount</th><th>customer_id</th><th>nameDest</th><th>nameOrig</th><th>type</th><th>firstname</th><th>lastname</th><th>email</th><th>address</th><th>country</th><th>creation_date</th><th>age_group</th><th>countryOrig_name</th><th>countryDest_name</th></tr></thead><tbody><tr><td>3d1dd327-0120-495e-bb37-34008d7587a9</td><td>false</td><td>145273.89</td><td>5d64d91f-3d4d-4245-898a-390004585619</td><td>M7423407666</td><td>C5687240533</td><td>CASH_IN</td><td>Suzanne</td><td>Nixon</td><td>benitezkatherine@avila.biz</td><td>66602 Webb Land
# Lynnberg, UT 76294</td><td>AND</td><td>11-06-2022 00:00:00</td><td>1.0</td><td>Qatar</td><td>France</td></tr></tbody></table></div>

# %% [markdown]
# ## 📝 Function 2: Generate Fraud Report
# <div style="display: flex; align-items: center; gap: 15px;"> <img src="https://raw.githubusercontent.com/databricks-demos/dbdemos-resources/refs/heads/main/images/liza.png" style="width: 100px; border-radius: 10px;" /> <div> After gathering customer and transaction details, Liza’s next step is to automate the creation of professional fraud reports.<br> The <code>fraud_report_generator</code> function leverages generative AI to analyze transaction risk and produce clear, actionable documentation for both internal teams and customers.<br> This function: <ul> <li>Predicts whether a transaction is fraudulent using advanced AI models.</li> <li>Automatically generates a formal internal fraud report for the bank, summarizing key transaction details and investigation findings.</li> <li>Prepares a customer notification email with clear guidance and recommendations, personalized for the customer’s language and location when needed.</li> <li>Ensures all communications follow professional standards, with proper formatting and attention to compliance requirements.</li> </ul> By automating these steps, banks can accelerate fraud response, improve communication, and ensure consistent, audit-ready documentation for every flagged transaction. </div> </div>
#
# ### 🛠️ Next Step
# In the following section, we define the <code>fraud_report_generator</code> function, which will chain off of the <code>get_customer_details</code> function, in order to build an internal _and_ external fraud report both in English and in the given customer's natural language based on their demographic information.

# %%
prompt = """
You are a fraud detection assistant for banks, helping to identify and report potentially fraudulent transactions.

### Tools Available:
1. **get_customer_details** – Retrieves customer KYC profile, transaction history, and risk indicators for a given **Transaction ID**.

### Your Role:
- **If a transaction is fraudulent:**
    - **Internal Fraud Report:** Generate a professional fraud report for internal banking use, including:
        - Transaction ID, Customer ID, date/time, transaction amount, channel (e.g., online, ATM), and relevant risk indicators (e.g., velocity, geo-location anomaly, device mismatch).
        - Summary of investigation findings (e.g., pattern detected, rule triggered, behavioral anomaly).
        - Recommended actions (e.g., file SAR, freeze account, escalate to compliance).
        - Use clear, structured language and banking terminology.
    - **Customer Notification:** Draft a formal email to the customer:
        - Greet customer by first name.
        - Clearly state that suspicious activity was detected on their account.
        - Advise next steps (e.g., contact fraud team, monitor account, card reissue).
        - If the customer’s country is not English-speaking, also provide the email in their native language.
        - Use a professional, reassuring tone and proper formatting.
        - Do not include a closing.
    - Ensure all details match the provided **Transaction ID** and **Customer ID** before proceeding.

- **If the transaction is not fraudulent:**  
    - Briefly confirm that the transaction is legitimate and can be processed.

- Do not provide your reasoning step; just give the response.
"""

# %%
spark.sql("DROP FUNCTION IF EXISTS fraud_report_generator")

spark.sql(f"""
  CREATE OR REPLACE FUNCTION fraud_report_generator(
    id STRING, 
    is_fraud BOOLEAN, 
    amount DOUBLE, 
    customer_id STRING, 
    nameDest STRING, 
    nameOrig STRING, 
    type STRING, 
    firstname STRING, 
    lastname STRING, 
    email STRING, 
    address STRING, 
    country STRING, 
    creation_date STRING, 
    age_group DOUBLE,  
    countryOrig_name STRING, 
    countryDest_name STRING 
  )
  RETURNS STRING
  LANGUAGE SQL
  COMMENT "This function generates a fraud report based on the transaction details and customer information."
  RETURN (
    SELECT ai_query(
      'databricks-meta-llama-3-1-405b-instruct', 
      CONCAT(
        "{prompt}",
        'Transaction and customer details: ', 
        TO_JSON(NAMED_STRUCT(
          'id', id, 
          'is_fraud', is_fraud, 
          'amount', amount, 
          'customer_id', customer_id, 
          'nameDest', nameDest, 
          'nameOrig', nameOrig,  
          'type', type, 
          'firstname', firstname, 
          'lastname', lastname, 
          'email', email, 
          'address', address, 
          'country', country, 
          'creation_date', creation_date,
          'age_group', age_group, 
          'countryOrig_name', countryOrig_name, 
          'countryDest_name', countryDest_name
        ))
      )
    )
  )
""")
# Out:
# DataFrame[]

# %% [markdown]
# ### Example:
#
# Let's generate a report for a fraudulent transaction.

# %%
# %sql
SELECT fraud_report_generator(
    '001df0ff-a9a6-4b94-a548-bfb6d5393698', true,	400000,	'80a60ee7-a482-4e69-aa8f-2914f051f5b5',	'CC0290993355',	'C0047984490',	'TRANSFER',	'Angela',	'Tran',	'eburch@smith.com',	'282 Amanda Road Apt. 209 Matthewview, GU 81248' ,	'GRC',	'2021-11-05',	6,	'France',	'Nigeria'
  ) as transaction_report
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>transaction_report</th></tr></thead><tbody><tr><td>**Internal Fraud Report**
#
# **Transaction Details:**
#
# * Transaction ID: 001df0ff-a9a6-4b94-a548-bfb6d5393698
# * Customer ID: 80a60ee7-a482-4e69-aa8f-2914f051f5b5
# * Date/Time: 2021-11-05
# * Transaction Amount: 400,000.00
# * Channel: Online
# * Relevant Risk Indicators:
# 	+ Geo-location anomaly (transaction originated from France and destined for Nigeria)
# 	+ Velocity (large transaction amount in a short period)
#
# **Investigation Findings:**
#
# Our system detected a suspicious transaction on the account of Angela Tran, which triggered a review. Upon investigation, we found that the transaction amount of 400,000.00 is unusually high and exceeds the customer's normal spending patterns. Additionally, the transaction originated from France and was destined for Nigeria, which raises concerns about potential money laundering.
#
# **Recommended Actions:**
#
# 1. File a Suspicious Activity Report (SAR) with the relevant authorities.
# 2. Freeze the customer's account to prevent further suspicious activity.
# 3. Escalate the case to the compliance team for further review and potential reporting to regulatory bodies.
#
# **Customer Notification:**
#
# Subject: Suspicious Activity Detected on Your Account
#
# Dear Angela,
#
# We are writing to inform you that our system has detected suspicious activity on your account. As a precautionary measure, we have temporarily frozen your account to prevent any further unauthorized transactions.
#
# We kindly request that you contact our fraud team at your earliest convenience to discuss this matter further. In the meantime, we recommend that you monitor your account activity closely and report any discrepancies to us immediately.
#
# We apologize for any inconvenience this may cause and appreciate your prompt attention to this matter.
#
# [ Greek translation ]
#
# Θέμα: Ανίχνευση ύποπτης δραστηριότητας στο λογαριασμό σας
#
# Αγαπητή Angela,
#
# Σας ενημερώνουμε ότι το σύστημά μας ανίχνευσε ύποπτη δραστηριότητα στο λογαριασμό σας. Ως προληπτικό μέτρο, έχουμε προσωρινά παγώσει το λογαριασμό σας για να αποτρέψουμε οποιαδήποτε περαιτέρω μη εξουσιοδοτημένες συναλλαγές.
#
# Σας ζητάμε να επικοινωνήσετε με την ομάδα απάτης μας το συντομότερο δυνατό για να συζητήσουμε περαιτέρω το θέμα αυτό. Εν τω μεταξύ, σας συνιστούμε να παρακολουθήσετε στενά τη δραστηριότητα του λογαριασμού σας και να αναφέρετε οποιαδήποτε αποκλίσεις σε εμάς αμέσως.
#
# Λυπούμαστε για οποιαδήποτε αναστάτωση που μπορεί να προκληθεί και εκτιμούμε την άμεση προσοχή σας σε αυτό το θέμα.</td></tr></tbody></table></div>

# %% [markdown]
# ### Example:
#
# Now, let's generate a report for a transaction that is not fraudulent. Unhappy with output? Modify the prompt in cell 11!

# %%
# %sql
SELECT fraud_report_generator(
    '3d1dd327-0120-495e-bb37-34008d7587a9', false, 145273.89, '5d64d91f-3d4d-4245-898a-390004585619', 'M7423407666', 'C5687240533', 'CASH_IN', 'Suzanne', 'Nixon', 'benitezkatherine@avila.biz', '66602 Webb Land Lynnberg, UT 76294', 'AND', '2022-11-06', 1, 'Qatar', 'France'
) as transaction_report
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>transaction_report</th></tr></thead><tbody><tr><td>**Transaction Legitimacy Confirmation**
#
# The transaction with ID "3d1dd327-0120-495e-bb37-34008d7587a9" is legitimate and can be processed.</td></tr></tbody></table></div>

# %% [markdown]
# ## 🚀 Operation 3: Apply Our Functions in Batch to Suspicious Transactions
#
# <div style="display: flex; align-items: center; gap: 15px;">
#   <img src="https://raw.githubusercontent.com/databricks-demos/dbdemos-resources/refs/heads/main/images/liza.png"
#        style="width: 100px; border-radius: 10px;" />
#   <div>
#     Now that Liza has implemented the <code>get_customer_details</code> and <code>fraud_report_generator</code> functions, the next step is to scale these operations by applying them in batch to a dataset of suspicious transactions.
#     This operation enables organizations to:
#     <ul>
#       <li>Process large volumes of historical or real-time transactions efficiently</li>
#       <li>Generate detailed reports for flagged transactions based on predefined criteria (e.g., unusual amounts or behavioral anomalies)</li>
#       <li>Democratize access to enriched transaction data for auditors and fraud investigators</li>
#       <li>Identify patterns across multiple transactions for fraud detection and risk analysis</li>
#     </ul>
#     By leveraging Databricks' scalable compute capabilities, this batch processing operation ensures that even large datasets can be analyzed quickly and effectively.
#   </div>
# </div>
#
# ### 🛠️ Next Step
# In the following section, we demonstrate how to apply the <code>get_customer_details</code> and <code>fraud_report_generator</code> functions in batch mode to process suspicious transactions. This includes:
# 1. Loading a dataset of flagged transactions from Unity Catalog.
# 2. Iteratively applying the functions to generate reports for each transaction.
# 3. Storing the enriched reports back into Unity Catalog for downstream analysis.
#
# <small>💡 Batch processing unlocks insights from historical transaction data, enabling proactive fraud detection and improved operational efficiency.</small>

# %%
# %sql
CREATE OR REPLACE TABLE fraudulent_transactions_report_table AS
SELECT 
  id AS id,
  is_fraud,
  fraud_report_generator(
    id, 
    is_fraud, 
    amount, 
    customer_id, 
    nameDest, 
    nameOrig, 
    type, 
    firstname, 
    lastname, 
    email, 
    address, 
    country, 
    creation_date, 
    age_group,  
    countryOrig_name, 
    countryDest_name
  ) AS claim_report
FROM (
  SELECT *
  FROM gold_transactions
  WHERE is_fraud = true
  LIMIT 5
);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## Example
#
# Below are fraud reports for five fraudulent transactions. Want to apply the report generator to all of your data? Modify the previous table generation cell.

# %%
# %sql
SELECT * FROM fraudulent_transactions_report_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>is_fraud</th><th>claim_report</th></tr></thead><tbody><tr><td>d9c598b3-1c84-4f2a-9c23-dfd8f9d11942</td><td>true</td><td>**Internal Fraud Report**
#
# **Transaction Details:**
#
# * Transaction ID: d9c598b3-1c84-4f2a-9c23-dfd8f9d11942
# * Customer ID: 0007abd1-2fbd-4756-ad25-22c3e6f2f6de
# * Date/Time: 12-08-2022 00:00:00
# * Transaction Amount: 395,519.34
# * Channel: Online
# * Relevant Risk Indicators:
# 	+ Velocity anomaly detected
# 	+ Geo-location anomaly detected (transaction originated from France, but customer's country is Angola)
# 	+ Device mismatch detected
#
# **Investigation Findings:**
#
# Our system detected a suspicious transaction on the account of Patrick Reyes, which triggered a velocity anomaly alert. Further investigation revealed a geo-location anomaly, as the transaction originated from France, whereas the customer's country is Angola. Additionally, a device mismatch was detected, indicating potential unauthorized access to the account.
#
# **Recommended Actions:**
#
# 1. File a Suspicious Activity Report (SAR) with the relevant authorities.
# 2. Freeze the customer's account to prevent further potential fraudulent activity.
# 3. Escalate the case to the compliance team for further review and investigation.
#
# **Customer Notification:**
#
# Subject: Suspicious Activity Detected on Your Account
#
# Dear Patrick,
#
# We are writing to inform you that our system has detected suspicious activity on your account. We take the security of your account very seriously and have taken immediate action to protect your funds.
#
# We recommend that you contact our fraud team immediately to discuss this further and take necessary steps to secure your account. We also advise you to closely monitor your account activity and report any further suspicious transactions to us.
#
# We apologize for any inconvenience this may cause and appreciate your prompt attention to this matter.
#
# [ Portuguese translation for Angola ]
#
# Assunto: Atividade Suspeita Detectada na Sua Conta
#
# Prezado Patrick,
#
# Estamos a escrever para informar que o nosso sistema detectou atividade suspeita na sua conta. Nós levamos muito a sério a segurança da sua conta e tomamos medidas imediatas para proteger os seus fundos.
#
# Recomendamos que entre em contacto com a nossa equipa de fraude imediatamente para discutir este assunto e tomar as medidas necessárias para segurar a sua conta. Também aconselhamos a monitorizar de perto a atividade da sua conta e reportar qualquer transação suspeita adicional para nós.
#
# Lamentamos qualquer inconveniente que isso possa causar e apreciamos a sua atenção imediata a este assunto.</td></tr><tr><td>7f4abd00-651f-482a-8496-c356df95ada7</td><td>true</td><td>**Internal Fraud Report**
#
# **Transaction Details:**
#
# * Transaction ID: 7f4abd00-651f-482a-8496-c356df95ada7
# * Customer ID: 001d6d01-06fb-42b2-a720-62003747366d
# * Date/Time: 12-28-2021 00:00:00
# * Transaction Amount: $400,000.00
# * Channel: CASH_OUT
# * Relevant Risk Indicators:
# 	+ Velocity anomaly detected
# 	+ Geo-location anomaly detected (transaction originated from Cambodia, but customer's country is Madagascar)
#
# **Investigation Findings:**
#
# Our system detected a suspicious transaction on the account of Robert Butler, which triggered a velocity and geo-location anomaly alert. Upon further investigation, it appears that the transaction is indeed fraudulent.
#
# **Recommended Actions:**
#
# 1. File a Suspicious Activity Report (SAR) with the relevant authorities.
# 2. Freeze the customer's account to prevent further unauthorized transactions.
# 3. Escalate the case to the compliance team for further review and action.
#
# **Customer Notification:**
#
# Subject: Suspicious Activity Detected on Your Account
#
# Dear Robert,
#
# We are writing to inform you that our system has detected suspicious activity on your account. We take the security of your account very seriously and have taken immediate action to protect your funds.
#
# We recommend that you contact our fraud team immediately to discuss this further and take steps to secure your account. We also advise you to monitor your account closely for any further suspicious activity.
#
# We apologize for any inconvenience this may cause and appreciate your prompt attention to this matter.
#
# [Note: As the customer's country is Madagascar, a French-speaking country, the email will also be sent in French.]
#
# Objet: Activité suspecte détectée sur votre compte
#
# Cher Robert,
#
# Nous vous écrivons pour vous informer que notre système a détecté une activité suspecte sur votre compte. Nous prenons très au sérieux la sécurité de votre compte et avons pris des mesures immédiates pour protéger vos fonds.
#
# Nous vous recommandons de contacter notre équipe de fraude immédiatement pour discuter de cela plus en détail et prendre des mesures pour sécuriser votre compte. Nous vous conseillons également de surveiller étroitement votre compte pour toute activité suspecte supplémentaire.
#
# Nous nous excusons pour tout inconvénient que cela pourrait causer et apprécions votre attention prompte à cette affaire.</td></tr><tr><td>131bf5ee-7ae5-41db-a59d-056c47bf8bed</td><td>true</td><td>**Internal Fraud Report**
#
# **Transaction Details:**
#
# * Transaction ID: 131bf5ee-7ae5-41db-a59d-056c47bf8bed
# * Customer ID: 002c7df2-b64c-42cf-b4d3-75aadf0e4b8e
# * Date/Time: 09-27-2021 00:00:00
# * Transaction Amount: 400,000.00
# * Channel: CASH_OUT
# * Relevant Risk Indicators:
# 	+ Geo-location anomaly (country of origin: Spain, country of destination: Russian Federation)
# 	+ High-value transaction
#
# **Investigation Findings:**
#
# Our system has detected a suspicious transaction on the account of Roger Coleman, which has been flagged for review. The transaction involves a large cash out amount of 400,000.00, which is unusual for this customer. Furthermore, the transaction involves a geo-location anomaly, as the country of origin is Spain, while the country of destination is the Russian Federation.
#
# **Recommended Actions:**
#
# 1. File a Suspicious Activity Report (SAR) with the relevant authorities.
# 2. Freeze the customer's account to prevent further suspicious activity.
# 3. Escalate the case to the compliance team for further review and investigation.
#
# **Customer Notification:**
#
# Subject: Important: Suspicious Activity Detected on Your Account
#
# Dear Roger,
#
# We are writing to inform you that our system has detected suspicious activity on your account. We take the security of your account very seriously and want to assure you that we are taking immediate action to protect your interests.
#
# We have reason to believe that a recent transaction on your account may be fraudulent. We urge you to contact our fraud team immediately to discuss this further. In the meantime, we recommend that you closely monitor your account activity and report any further suspicious transactions to us.
#
# We may need to reissue your card or take other steps to secure your account. We will be in touch with you shortly to discuss the next steps.
#
# Please find below the Polish translation of this email:
#
# Temat: Ważne: Wykryto podejrzane działanie na Twoim koncie
#
# Szanowny Roger,
#
# Piszę, aby poinformować, że nasz system wykrył podejrzane działanie na Twoim koncie. Traktujemy bezpieczeństwo Twojego konta bardzo poważnie i chcemy zapewnić, że podejmujemy natychmiastowe działania w celu ochrony Twoich interesów.
#
# Mamy powody, aby sądzić, że ostatnia transakcja na Twoim koncie może być nielegalna. Zachęcamy do natychmiastowego kontaktu z naszym zespołem ds. oszustw w celu omówienia tej sprawy. W międzyczasie zalecamy ścisłe monitorowanie aktywności na Twoim koncie i zgłaszanie wszelkich dalszych podejrzanych transakcji nam.
#
# Może być konieczne ponowne wydanie karty lub pod

# %% [markdown]
# ## Next Steps
#
# Proceed to notebook **05.2-Agent-Creation-Guide** in order to package the above functions into an implementable AI Agent with Databricks!
