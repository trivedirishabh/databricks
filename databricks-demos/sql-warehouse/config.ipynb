# %% [markdown]
# ## Configuration file
#
# Please change your catalog and schema here to run the demo on a different catalog.
#
# <!-- Collect usage data (view). Remove it to disable collection or disable tracker during installation. View README for more details.  -->
# <img width="1px" src="https://ppxrzfxige.execute-api.us-west-2.amazonaws.com/v1/analytics?category=DBSQL&org_id=2162748966026566&notebook=%2Fconfig&demo_name=sql-warehouse&event=VIEW&path=%2F_dbdemos%2FDBSQL%2Fsql-warehouse%2Fconfig&version=1">

# %%
catalog = "main"
dbName = db = "dbdemos_sql_warehouse"
