# %% [markdown]
# # What is Databricks Auto Loader?
#
# <img src="https://github.com/QuentinAmbard/databricks-demo/raw/main/product_demos/autoloader/autoloader-edited-anim.gif" style="float:right; margin-left: 10px" />
#
# [Databricks Auto Loader](https://docs.databricks.com/ingestion/auto-loader/index.html) lets you scan a cloud storage folder (S3, ADLS, GS) and only ingest the new data that arrived since the previous run.
#
# This is called **incremental ingestion**.
#
# Auto Loader can be used in a near real-time stream or in a batch fashion, e.g., running every night to ingest daily data.
#
# Auto Loader provides a strong gaurantee when used with a Delta sink (the data will only be ingested once).
#
# ## How Auto Loader simplifies data ingestion
#
# Ingesting data at scale from cloud storage can be really hard at scale. Auto Loader makes it easy, offering these benefits:
#
#
# * **Incremental** & **cost-efficient** ingestion (removes unnecessary listing or state handling)
# * **Simple** and **resilient** operation: no tuning or manual code required
# * Scalable to **billions of files**
#   * Using incremental listing (deprecated, relies on filename order)
#   * Leveraging notification + message queue (recommended)
# * **Schema inference** and **schema evolution** are handled out of the box for most formats (csv, json, avro, images...)
#
# <!-- Collect usage data (view). Remove it to disable collection. View README for more details.  -->
# <img width="1px" src="https://ppxrzfxige.execute-api.us-west-2.amazonaws.com/v1/analytics?category=data-engineering&org_id=2162748966026566&notebook=%2F02-Auto-loader-schema-evolution-Ingestion&demo_name=data-ingestion&event=VIEW&path=%2F_dbdemos%2Fdata-engineering%2Fdata-ingestion%2F02-Auto-loader-schema-evolution-Ingestion&version=1">

# %%
# %run ./_resources/00-setup $reset_all_data=false
# Out:
# USE CATALOG `main__build`
# using catalog.database `main__build`.`dbdemos_data_ingestion`
# data already existing. Run with reset_all_data=true to force a data cleanup for your local demo.
# False

# %%
display(spark.read.text(volume_folder+'/user_json'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>value</th></tr></thead><tbody><tr><td>{"id":10665,"creation_date":"07-01-2025 16:51:36","firstname":"Antonio","lastname":"Johnson","email":"fordsteven@moore.com","address":"241 Veronica Islands Suite 936 Lake Chelsea HI 69280","gender":1.0,"age_group":5.0}</td></tr><tr><td>{"id":11334,"creation_date":"07-10-2025 13:34:34","firstname":"Shane","lastname":"West","email":"sanchezeric@williams-cohen.com","address":"Unit 3560 Box 2007 DPO AP 41729","gender":1.0,"age_group":3.0}</td></tr><tr><td>{"id":2567,"creation_date":"07-04-2025 10:51:16","firstname":"Evan","lastname":"Martin","email":"alvarezkathleen@wright.com","address":"37829 Stephen Path Andrewtown PW 67701","gender":1.0,"age_group":3.0}</td></tr><tr><td>{"id":230,"creation_date":"07-10-2025 00:57:07","firstname":"Rodney","lastname":"Henderson","email":"woodlance@stewart-mitchell.org","address":"7021 Ricky Keys Port Kathryn MI 90090","gender":0.0,"age_group":3.0}</td></tr><tr><td>{"id":11771,"creation_date":"07-18-2025 11:22:38","firstname":"Lori","lastname":"Cardenas","email":"clarsen@reyes.com","address":"851 Sullivan Port Suite 759 Valdezside MT 73591","gender":1.0,"age_group":0.0}</td></tr><tr><td>{"id":1132,"creation_date":"07-08-2025 13:52:52","firstname":"Michael","lastname":"Kelly","email":"amandaweiss@fowler-miller.info","address":"83210 Evans Club Lake Carlosside RI 94498","gender":0.0,"age_group":7.0}</td></tr><tr><td>{"id":5145,"creation_date":"07-06-2025 16:04:15","firstname":"Joseph","lastname":"Baker","email":"youngjason@herrera-jackson.org","address":"9419 Robert Viaduct Johnside VA 89098","gender":1.0,"age_group":0.0}</td></tr><tr><td>{"id":3693,"creation_date":"07-11-2025 05:37:57","firstname":"Timothy","lastname":"Mendoza","email":"gespinoza@taylor.com","address":"1281 Mann Manors Suite 998 Port Susan MI 51394","gender":1.0,"age_group":9.0}</td></tr><tr><td>{"id":6520,"creation_date":"07-05-2025 01:32:55","firstname":"James","lastname":"Lee","email":"lowens@gould-gonzalez.com","address":"6598 Randy Road Suite 661 Port Alexandertown AR 77754","gender":1.0,"age_group":5.0}</td></tr><tr><td>{"id":5488,"creation_date":"07-20-2025 01:26:35","firstname":"Patricia","lastname":"Orozco","email":"harrisondenise@sanders-hughes.com","address":"05041 Patricia Mission Torresmouth OH 78086","gender":1.0,"age_group":9.0}</td></tr><tr><td>{"id":5074,"creation_date":"07-03-2025 04:16:08","firstname":"Curtis","lastname":"Garcia","email":"gilbertstephen@gonzales.com","address":"39989 Watson Gardens Apt. 934 South Cassandraside MH 76883","gender":1.0,"age_group":2.0}</td></tr><tr><td>{"id":7030,"creation_date":"07-18-2025 06:16:48","firstname":"Lindsey","lastname":"Stokes","email":"knightpaul@smith.info","address":"1405 Alexander View Brandonhaven SD 40732","gender":1.0,"age_group":7.0}</td></tr><tr><td>{"id":425,"creation_date":"07-12-2025 20:09:39","firstname":"Angela","lastname":"Spencer","email":"vanessa05@jones.biz","address":"774 Richard Vista Ramosland HI 87358","gender":1.0,"age_group":10.0}</td></tr><tr><td>{"id":6756,"creation_date":"07-08-2025 11:48:53","firstname":"Michael","lastname":"Bell","email":"fmarquez@williamson.biz","address":"260 Danielle Harbor Lake Nicholasview NY 93882","gender":1.0,"age_group":9.0}</td></tr><tr><td>{"id":2852,"creation_date":"07-17-2025 04:57:50","firstname":"Katherine","lastname":"Malone","email":"heather63@hendricks.com","address":"3040 Garrison Row New Paulmouth IA 55160","gender":0.0,"age_group":3.0}</td></tr><tr><td>{"id":12166,"creation_date":"07-15-2025 16:06:56","firstname":"Gloria","lastname":"Mcdaniel","email":"edward65@melton-fisher.com","address":"3835 Melissa Lakes Port Natashamouth MD 93672","gender":1.0,"age_group":6.0}</td></tr><tr><td>{"id":11043,"creation_date":"07-05-2025 08:31:13","firstname":"James","lastname":"Harris","email":"rodriguezalicia@chan-massey.net","address":"195 Angel Center Apt. 354 ...

# %% [markdown]
# ### Auto Loader basics
# Let's create a new Auto Loader stream that will incrementally ingest new incoming files.
#
# In this example we will specify the full schema. We will also use `cloudFiles.maxFilesPerTrigger` to take 1 file a time to simulate a process adding files 1 by 1.

# %%
bronzeDF = (spark.readStream \
                .format("cloudFiles")
                .option("cloudFiles.format", "json")
                .option("cloudFiles.maxFilesPerTrigger", "1")  #demo only, remove in real stream
                .schema("address string, creation_date string, firstname string, lastname string, id bigint")
                .load(volume_folder+'/user_json'))
display(bronzeDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
Donald Estate Suite 545 Darrellton IL 05354</td><td>07-04-2025 15:33:25</td><td>George</td><td>Jackson</td><td>3234</td></tr><tr><td>USS Hampton FPO AA 48326</td><td>07-13-2025 19:26:06</td><td>Carol</td><td>Greene</td><td>8945</td></tr><tr><td>47463 Wilson Locks East Kerriside AL 20267</td><td>07-20-2025 08:28:43</td><td>Rebecca</td><td>Knox</td><td>10736</td></tr><tr><td>2368 Lisa Flats Suite 690 East Kimberlyburgh PR 72725</td><td>07-18-2025 23:40:38</td><td>Megan</td><td>Kirby</td><td>11788</td></tr><tr><td>47286 Cindy Via North Emilyton WI 03301</td><td>07-19-2025 18:07:02</td><td>Natalie</td><td>Johns</td><td>6854</td></tr><tr><td>142 Marks Row Port Jonton MI 96431</td><td>07-20-2025 02:16:49</td><td>Patricia</td><td>Kline</td><td>10740</td></tr><tr><td>33361 Adams Point North Erika WY 39978</td><td>07-06-2025 00:43:00</td><td>Joe</td><td>Young</td><td>3577</td></tr><tr><td>PSC 8304 Box 0966 APO AP 98789</td><td>07-15-2025 02:45:28</td><td>Donna</td><td>Guerrero</td><td>1634</td></tr><tr><td>Unit 6029 Box 8795 DPO AE 90385</td><td>07-14-2025 09:47:47</td><td>Courtney</td><td>Burton</td><td>10576</td></tr><tr><td>419 Megan Ports Apt. 433 West Shannonfurt NE 09709</td><td>07-02-2025 11:11:04</td><td>Casey</td><td>Jones</td><td>4885</td></tr><tr><td>661 Jeremy Plain Suite 180 Karenhaven HI 92870</td><td>07-19-2025 08:19:31</td><td>Michele</td><td>Villarreal</td><td>854</td></tr><tr><td>26356 Jay Trace Lake Courtney MA 52196</td><td>07-15-2025 20:17:15</td><td>Heather</td><td>Dominguez</td><td>356</td></ ...

# %% [markdown]
# ## Schema inference
# Specifying the schema manually can be a challenge, especially with dynamic JSON. Notice that we are missing the "age" data because we overlooked specifying this column in the schema.
#
# * Schema inference has always been expensive and slow at scale, but not with Auto Loader. Auto Loader efficiently samples data to infer the schema and stores it under `cloudFiles.schemaLocation` in your bucket.
# * Additionally, `cloudFiles.inferColumnTypes` will determine the proper data type from your JSON.
#
# Let's redefine our stream with these features. Notice that we now have all of the JSON fields.
#
# *Notes:*
# * *With Spark Declarative Pipelines you don't even have to set this option, the engine manages the schema location for you.*
# * *Sampling size can be changed with `spark.databricks.cloudFiles.schemaInference.sampleSize.numBytes`*

# %%
bronzeDF = (spark.readStream
                .format("cloudFiles")
                .option("cloudFiles.format", "json")
                .option("cloudFiles.schemaLocation", volume_folder+'/inferred_schema')
                .option("cloudFiles.inferColumnTypes", "true")
                .load(volume_folder+'/user_json'))
display(bronzeDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
Angela</td><td>1.0</td><td>425</td><td>Spencer</td><td>null</td><td>null</td></tr><tr><td>260 Danielle Harbor Lake Nicholasview NY 93882</td><td>9.0</td><td>07-08-2025 11:48:53</td><td>fmarquez@williamson.biz</td><td>Michael</td><td>1.0</td><td>6756</td><td>Bell</td><td>null</td><td>null</td></tr><tr><td>3040 Garrison Row New Paulmouth IA 55160</td><td>3.0</td><td>07-17-2025 04:57:50</td><td>heather63@hendricks.com</td><td>Katherine</td><td>0.0</td><td>2852</td><td>Malone</td><td>null</td><td>null</td></tr><tr><td>3835 Melissa Lakes Port Natashamouth MD 93672</td><td>6.0</td><td>07-15-2025 16:06:56</td><td>edward65@melton-fisher.com</td><td>Gloria</td><td>1.0</td><td>12166</td><td>Mcdaniel</td><td>null</td><td>null</td></tr><tr><td>195 Angel Center Apt. 354 South Dominic ID 02248</td><td>10.0</td><td>07-05-2025 08:31:13</td><td>rodriguezalicia@chan-massey.net</td><td>James</td><td>0.0</td><td>11043</td><td>Harris</td><td>null</td><td>null</td></t ...

# %% [markdown]
# ### Schema hints
# You might need to enforce a part of your schema, e.g., to convert a timestamp. This can easily be done with Schema Hints.
#
# In this case, we'll make sure that the `id` is read as `bigint` and not `int`:

# %%
bronzeDF = (spark.readStream
                .format("cloudFiles")
                .option("cloudFiles.format", "json")
                .option("cloudFiles.schemaLocation", f"{volume_folder}/inferred_schema")
                .option("cloudFiles.inferColumnTypes", "true")
                .option("cloudFiles.schemaHints", "id bigint")
                .load(volume_folder+'/user_json'))
display(bronzeDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>address</th><th>age_group</th><th>creation_date</th><th>email</th><th>firstname</th><th>gender</th><th>id</th><th>lastname</th><th>new_column</th><th>_rescued_data</th></tr></thead><tbody><tr><td>241 Veronica Islands Suite 936 Lake Chelsea HI 69280</td><td>5.0</td><td>07-01-2025 16:51:36</td><td>fordsteven@moore.com</td><td>Antonio</td><td>1.0</td><td>10665</td><td>Johnson</td><td>null</td><td>null</td></tr><tr><td>Unit 3560 Box 2007 DPO AP 41729</td><td>3.0</td><td>07-10-2025 13:34:34</td><td>sanchezeric@williams-cohen.com</td><td>Shane</td><td>1.0</td><td>11334</td><td>West</td><td>null</td><td>null</td></tr><tr><td>37829 Stephen Path Andrewtown PW 67701</td><td>3.0</td><td>07-04-2025 10:51:16</td><td>alvarezkathleen@wright.com</td><td>Evan</td><td>1.0</td><td>2567</td><td>Martin</td><td>null</td><td>null</td></tr><tr><td>7021 Ricky Keys Port Kathryn MI 90090</td><td>3.0</td><td>07-10-2025 00:57:07</td><td>woodlance@stewart-mitchell.org</td><td>Rodney</td><td>0.0</td><td>230</td><td>Henderson</td><td>null</td><td>null</td></tr><tr><td>851 Sullivan Port Suite 759 Valdezside MT 73591</td><td>0.0</td><td>07-18-2025 11:22:38</td><td>clarsen@reyes.com</td><td>Lori</td><td>1.0</td><td>11771</td><td>Cardenas</td><td>null</td><td>null</td></tr><tr
 934 South Cassandraside MH 76883</td><td>2.0</td><td>07-03-2025 04:16:08</td><td>gilbertstephen@gonzales.com</td><td>Curtis</td><td>1.0</td><td>5074</td><td>Garcia</td><td>null</td><td>null</td></tr><tr><td>1405 Alexander View Brandonhaven SD 40732</td><td>7.0</td><td>07-18-2025 06:16:48</td><td>knightpaul@smith.info</td><td>Lindsey</td><td>1.0</td><td>7030</td><td>Stokes</td><td>null</td><td>null</td></tr><tr><td>774 Richard Vista Ramosland HI 87358</td><td>10.0</td><td>07-12-2025 20:09:39</td><td>vanessa05@jones.biz</td><td>Angela</td><td>1.0</td><td>425</td><td>Spencer</td><td>null</td><td>null</td></tr><tr><td>260 Danielle Harbor Lake Nicholasview NY 93882</td><td>9.0</td><td>07-08-2025 11:48:53</td><td>fmarquez@williamson.biz</td><td>Michael</td><td>1.0</td><td>6756</td><td>Bell</td><td>null</td><td>null</td></tr><tr><td>3040 Garrison Row New Paulmouth IA 55160</td><td>3.0</td><td>07-17-2025 04:57:50</td><td>heather63@hendricks.com</td><td>Katherine</td><td>0.0</td><td>2852</td><td>Malone</td><td>null</td><td>null</td></tr><tr><td>3835 Melissa Lakes Port Natashamouth MD 93672</td><td>6.0</td><td>07-15-2025 16:06:56</td><td>edward65@melton-fisher.com</td><td>Gloria</td><td>1.0</td><td>12166</td><td>Mcdaniel</td><td>null</td><td>null</td></tr><tr><td>195 Angel Center Apt. 354 South Dominic ID 02248</td><td>10.0</td><td>07-05-2025 08:31:13</td><td>rodriguezalicia@chan-massey.net</td><td>James</td><td>0.0</td><td>11043</td><td>Harris</td><td>null</td><td>null</td></t ...

# %% [markdown]
# ### Incorrect schema
# Auto Loader automatically recovers from incorrect schema and conflicting type. It'll save incorrect data in the `_rescued_data` column.

# %%
from pyspark.sql import Row
data = [Row(email="quentin.ambard@databricks.com", firstname="Quentin", id="456455", lastname="Ambard")]
incorrect_data = spark.createDataFrame(data)
incorrect_data.write.format("json").mode("append").save(volume_folder + "/user_json")

# %%
wait_for_rescued_data()
# Start the stream and filter on on the rescue column to see how the incorrect data is captured
display(get_stream().filter("_rescued_data is not null"))

# %% [markdown]
# ### Adding a new column
# By default the stream will tigger a `UnknownFieldException` exception on new column. You then have to restart the stream to include the new column.
#
# Make sure your previous stream is still running and run the next cell.
#
# *Notes*:
# * *See `cloudFiles.schemaEvolutionMode` for different behaviors and more details.*
# * *Don't forget to add `.writeStream.option("mergeSchema", "true")` to dynamically add when columns when writting to a delta table*

# %%
# Stop all the existing streams
DBDemos.stop_all_streams()

# Add 'new_column'
data = [Row(email="quentin.ambard@databricks.com", firstname="Quentin", id=456454, lastname="Ambard", new_column="test new column value")]
new_row = spark.createDataFrame(data)
new_row.write.format("json").mode("append").save(volume_folder + "/user_json")
# Out:
# Stopping 5 streams
# All stream stopped

# %%
# Existing stream wil fail with: org.apache.spark.sql.catalyst.util.UnknownFieldException: Encountered unknown field(s) during parsing: {"new_column":"test new column value"}
display(get_stream())

# %%
# We just have to restart it to capture the new data. Let's filter on the new column to make sure we have the proper row 
# (re-run the cell)
display(get_stream().filter('new_column is not null'))

# %% [markdown]
# ## Ingesting a high volume of input files
# Scanning folders with many files to detect new data is an expensive operation, leading to ingestion challenges and higher cloud storage costs.
#
# To solve this issue and support an efficient listing, Databricks autoloader offers two modes:
#
# - Incremental listing with `cloudFiles.useIncrementalListing` (deprecated), based on the alphabetical order of the file's path to only scan new data: (`ingestion_path/YYYY-MM-DD`)
# - Notification system, which sets up a managed cloud notification system sending new file name to a queue (recommended). See `cloudFiles.useNotifications` for more details.
#
# <img src="https://github.com/QuentinAmbard/databricks-demo/raw/main/product_demos/autoloader-mode.png" width="700"/>
#
# Use the notification system option whenever possible.

# %% [markdown]
# ## Support for images
# Databricks Auto Loader provides native support for images and binary files.
#
# <img src="https://github.com/QuentinAmbard/databricks-demo/raw/main/product_demos/autoloader-images.png" width="800" />
#
# Just set the format accordingly and the engine will do the rest: `.option("cloudFiles.format", "binaryFile")`
#
# Use-cases:
#
# - ETL images into a Delta table using Auto Loader
# - Automatically ingest continuously arriving new images
# - Easily retrain ML models on new images
# - Perform distributed inference using a pandas UDF directly from Delta

# %% [markdown]
# ## Deploying robust ingestion jobs in production
#
# Let's see how to use Auto Loader to ingest JSON files, support schema evolution, and automatically restart when a new column is found.
#
# If you need your job to be resilient with regard to an evolving schema, you have multiple options:
#
# * Let the full job fail & configure Databricks Workflow to restart it automatically
# * Leverage Spark Declarative Pipelines to simplify all the setup (SDP handles everything for you out of the box)
# * Wrap your call to restart the stream when the new column appears.
#
# Here is an example:

# %%
def start_stream_restart_on_schema_evolution():
  while True:
    try:
      q = (spark.readStream
                  .format("cloudFiles")
                  .option("cloudFiles.format", "json")
                  .option("cloudFiles.schemaLocation", f"{volume_folder}/inferred_schema")
                  .option("cloudFiles.inferColumnTypes", "true")
                  .load(volume_folder+"/user_json")
                .writeStream
                  .toTable("autoloader_demo_output",
                           checkpointLocation=volume_folder+"/checkpoint",
                           mergeSchema=True)
          )
      q.awaitTermination()
      return q
    except BaseException as e:
      # Adding a new column will trigger an UnknownFieldException. In this case we just restart the stream:
      if 'UNKNOWN_FIELD_EXCEPTION' in str(e):
        print(f"Going to restart stream after schema change:\n{e}")
      else:
        raise e

#Careful - this will run forever do not forget to stop your job/notebook after you tried!
# Seeing [INFINITE_STREAMING_TRIGGER_NOT_SUPPORTED] ? Interactive serverless isn't designed for unlimited streaming. See https://docs.databricks.com/en/compute/serverless/limitations.html#streaming
# Use a classic cluster, or you can use the writeStream.trigger(availableNow=True) option instead, or move your code to a Declarative Pipeline!
#start_stream_restart_on_schema_evolution()

# %% [markdown]
# ## Conclusion
#
# We've seen how Databricks Auto Loader can be used to easily ingest your files, solving all ingestion challenges!
#
# You're ready to use it in your projects!

# %%
DBDemos.stop_all_streams()
