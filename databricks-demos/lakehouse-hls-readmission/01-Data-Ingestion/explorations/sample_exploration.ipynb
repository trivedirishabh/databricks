-- %% [markdown]
-- ### Example Exploratory Notebook
-- Use this notebook to explore the data generated by the pipeline in your preferred programming language.
-- **Note**: This notebook is not executed as part of the pipeline.

-- %%
SELECT * FROM read_files("/Volumes/main/dbdemos_hls_readmission/synthea/landing_zone/encounters", format => "parquet" )
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT * FROM read_files("/Volumes/main/dbdemos_hls_readmission/synthea/landing_zone/patients", format => "parquet");
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT * FROM read_files("/Volumes/main/dbdemos_hls_readmission/synthea/landing_zone/conditions", format => "parquet");
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT * FROM read_files("/Volumes/main/dbdemos_hls_readmission/synthea/landing_zone/medications", format => "parquet");
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT * FROM read_files("/Volumes/main/dbdemos_hls_readmission/synthea/landing_zone/immunizations", format => "parquet");
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT * FROM read_files("/Volumes/main/dbdemos_hls_readmission/synthea/landing_vocab/CONCEPT", format => "parquet");
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT * FROM read_files("/Volumes/main/dbdemos_hls_readmission/synthea/landing_vocab/CONCEPT_RELATIONSHIP", format => "parquet");
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...
