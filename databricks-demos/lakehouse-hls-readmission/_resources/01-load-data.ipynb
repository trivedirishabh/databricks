# %%
dbutils.widgets.dropdown("reset_all_data", "false", ["true", "false"], "Reset all data")

# %% [markdown]
# Load data for the demo

# %%
# %run ./00-setup $reset_all_data=$reset_all_data $catalog=main $db=dbdemos_hls_readmission
