# %% [markdown]
# # Implement CDC: Change Data Capture
# ## Use-case: Synchronize your SQL Database with your Lakehouse
#
# Delta Lake is an <a href="https://delta.io/" target="_blank">open-source</a> storage layer with Transactional capabilities and increased Performances.
#
# Delta lake is designed to support CDC workload by providing support for UPDATE / DELETE and MERGE operation.
#
# In addition, Delta table can support CDC to capture internal changes and propagate the changes downstream.
#
# Note that this is a fairly advaned demo. Before going into this content, we recommend you get familiar with Delta Lake `dbdemos.install('delta-lake')`.
#
# ## Simplifying CDC with Spark Declarative Pipelines
#
# As you'll see, implementing a CDC pipeline from scratch is slightly advanced.
#
# To simplify these operation & implement a full CDC flow with SQL expression, we strongly advise to use Spark Declarative Pipelines with `APPLY CHANGES`: `dbdemos.install('pipeline-bike')` (including native SCDT2 support)
#
# As you'll see, `APPLY CHANGES` handles the MERGE INTO + DEDUPLICATION complexity for you.
#
#
# <!-- Collect usage data (view). Remove it to disable collection. View README for more details.  -->
# <img width="1px" src="https://ppxrzfxige.execute-api.us-west-2.amazonaws.com/v1/analytics?category=data-engineering&org_id=2162748966026566&notebook=%2F01-CDC-CDF-simple-pipeline&demo_name=cdc-pipeline&event=VIEW&path=%2F_dbdemos%2Fdata-engineering%2Fcdc-pipeline%2F01-CDC-CDF-simple-pipeline&version=1">

# %%
# %run ./_resources/00-setup $reset_all_data=false
# Out:
# USE CATALOG `main__build`
# using catalog.database `main__build`.`dbdemos_cdc_pipeline`
# data already existing. Run with reset_all_data=true to force a data cleanup for your local demo.

# %% [markdown]
# <img width="1000px" src="https://github.com/databricks-demos/dbdemos-resources/raw/main/images/product/Delta-Lake-CDC-CDF/delta_cdf.png" alt='Delta Lake Change Data Feed'/>

# %% [markdown]
# ## CDC flow
#
# Here is the flow we'll implement, consuming CDC data from an external database. Note that the incoming could be any format, including message queue such as Kafka.
#
# <img width="1000px" src="https://github.com/databricks-demos/dbdemos-resources/raw/main/images/product/Delta-Lake-CDC-CDF/cdc-flow-0.png" alt='Make all your data ready for BI and ML'/>

# %% [markdown]
# ## Bronze: Incremental data loading using Auto Loader
#
# <img src="https://github.com/databricks-demos/dbdemos-resources/raw/main/images/product/Delta-Lake-CDC-CDF/cdc-flow-1.png" alt='Make all your data ready for BI and ML' style='float: right' width='600'/>
#
# Working with external system can be challenging due to schema update. The external database can have schema update, adding or modifying columns, and our system must be robust against these changes.
#
# Databricks Autoloader (`cloudFiles`) handles schema inference and evolution out of the box.
#
# For more details on Auto Loader, run `dbdemos.install('auto-loader')`

# %%
cdc_raw_data = spark.read.option('header', "true").csv(raw_data_location+'/user_csv')
display(cdc_raw_data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>operation_date</th><th>name</th><th>email</th><th>address</th><th>operation</th></tr></thead><tbody><tr><td>273</td><td>2024-07-10T23:47:28.779Z</td><td>Blake</td><td>martinolivia@howard.com</td><td>4841 Berry GlensShannonville, PW 77461</td><td>APPEND</td></tr><tr><td>318</td><td>2024-07-10T23:47:28.779Z</td><td>Micheal</td><td>shepherdkayla@pena.com</td><td>2318 Alexandra Road Suite 543West Susanview, MH 11854</td><td>APPEND</td></tr><tr><td>147</td><td>2024-07-10T23:47:28.779Z</td><td>Mary</td><td>rfischer
><td>150</td><td>2024-07-10T23:47:28.779Z</td><td>Emily</td><td>hoffmanrobert@lindsey.com</td><td>0081 Danielle DrivesPort Kathleen, DC 15510</td><td>APPEND</td></tr><tr><td>259</td><td>2024-07-10T23:47:28.779Z</td><td>Jennifer</td><td>callahanbrenda@johnson-pittman.com</td><td>4389 Chris UnionWest Ronald, MD 14040</td><td>APPEND</td></tr><tr><td>502</td><td>2024-07-10T23:47:28.779Z</td><td>Alejandro</td><td>mejialisa@cannon.org</td><td>260 King Corner Apt. 744Billyton, RI 06051</td><td>APPEND</td></tr><tr><td>1162</td><td>2024-07-10T23:47:28.779Z</td><td> ...

# %%
display(cdc_raw_data.dropDuplicates(['operation']))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>operation_date</th><th>name</th><th>email</th><th>address</th><th>operation</th></tr></thead><tbody><tr><td>273</td><td>2024-07-10T23:47:28.779Z</td><td>Blake</td><td>martinolivia@howard.com</td><td>4841 Berry GlensShannonville, PW 77461</td><td>APPEND</td></tr><tr><td>0</td><td>2024-07-10T23:47:34.959Z</td><td>Megan</td><td>achang@green.info</td><td>48764 Howard Forge Apt. 421Vanessaside, VT 79393</td><td>DELETE</td></tr><tr><td>1000</td><td>2024-07-10T23:47:36.776Z</td><td>Megan</td><td>achang@green.info</td><td>48764 Howard Forge Apt. 421Vanessaside, VT 79393</td><td>UPDATE</td></tr></tbody></table></div>

# %%
bronzeDF = (spark.readStream
                .format("cloudFiles")
                .option("cloudFiles.format", "csv")
                #.option("cloudFiles.maxFilesPerTrigger", "1") #Simulate streaming, remove in production
                .option("cloudFiles.inferColumnTypes", "true")
                .option("cloudFiles.schemaLocation",  raw_data_location+"/stream/schema_cdc_raw")
                .option("cloudFiles.schemaHints", "id bigint, operation_date timestamp")
                .load(raw_data_location+'/user_csv'))

(bronzeDF.withColumn("file_name", col("_metadata.file_path")).writeStream
        .option("checkpointLocation", raw_data_location+"/stream/checkpoint_cdc_raw")
        .trigger(processingTime='10 seconds')
        #.trigger(availableNow=True) --use this trigger on serverless
        .table("clients_cdc"))

time.sleep(20)

# %%
# %sql
-- let's make sure our table has the proper compaction settings to support streaming
ALTER TABLE clients_cdc SET TBLPROPERTIES (delta.autoOptimize.optimizeWrite = true, delta.autoOptimize.autoCompact = true);

SELECT * FROM clients_cdc order by id asc ;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>operation_date</th><th>name</th><th>email</th><th>address</th><th>operation</th><th>_rescued_data</th><th>file_name</th><th>processing_time</th></tr></thead><tbody><tr><td>0</td><td>2024-07-10T23:47:28.779Z</td><td>Megan</td><td>achang@green.info</td><td>48764 Howard Forge Apt. 421Vanessaside, VT 79393</td><td>APPEND</td><td>null</td><td>/Volumes/main/dbdemos_cdc_pipeline/raw_data/user_csv/part-00002-tid-4633525547095067429-ae69ed69-27a1-4e4c-a649-5fcf0198765e-989-1-c000.csv</td><td>null</td></tr><tr><td>0</td><td>2024-07-10T23:47:34.959Z</td><td>Megan</td><td>achang@green.info</td><td>48764 Howard Forge Apt. 421Vanessaside, VT 79393</td><td>DELETE</td><td>null</td><td>/Volumes/main/dbdemos_cdc_pipeline/raw_data/user_csv/part-00000-tid-8563264077689375878-9275c5f4-1e62-4f78-9fa6-54
1e62-4f78-9fa6-54654edcdcbf-1010-1-c000.csv</td><td>null</td></tr><tr><td>3</td><td>2025-09-23T10:11:50Z</td><td>Updated_User_3</td><td>updated.user3@newcompany4.com</td><td>New_Address_330 Avenue</td><td>UPDATE</td><td>null</td><td>/Volumes/main/dbdemos_cdc_pipeline/raw_data/user_csv/cdc_events_20250923_101150_117.csv/part-00000-tid-911085739 ...

# %% [markdown]
# ## Silver: Materialize the table
#
# <img src="https://github.com/databricks-demos/dbdemos-resources/raw/main/images/product/Delta-Lake-CDC-CDF/cdc-flow-2.png" alt='Make all your data ready for BI and ML' style='float: right' width='600'/>
#
# The silver `retail_client_silver` table will contains the most up to date view. It'll be a replicat of the original MYSQL table.
#
# Because we'll propagate the `MERGE` operations downstream to the `GOLD` layer, we need to enable Delta Lake CDF: `delta.enableChangeDataFeed = true`

# %%
# %sql 
-- we can add NOT NULL in our ID field (or even more advanced constraint)
CREATE TABLE IF NOT EXISTS retail_client_silver (id BIGINT NOT NULL, name STRING, address STRING, email STRING, operation STRING) 
  TBLPROPERTIES (delta.enableChangeDataFeed = true, delta.autoOptimize.optimizeWrite = true, delta.autoOptimize.autoCompact = true);

# %%
#for each batch / incremental update from the raw cdc table, we'll run a MERGE on the silver table
def merge_stream(df, i):
  df.createOrReplaceTempView("clients_cdc_microbatch")
  #First we need to dedup the incoming data based on ID (we can have multiple update of the same row in our incoming data)
  #Then we run the merge (upsert or delete). We could do it with a window and filter on rank() == 1 too
  df.sparkSession.sql("""MERGE INTO retail_client_silver target
                                USING
                                (select id, name, address, email, operation from 
                                  (SELECT *, ROW_NUMBER() OVER (PARTITION BY id ORDER BY operation_date DESC) as rank from clients_cdc_microbatch) 
                                 where rank = 1
                                ) as source
                                ON source.id = target.id
                                WHEN MATCHED AND source.operation = 'DELETE' THEN DELETE
                                WHEN MATCHED AND source.operation != 'DELETE' THEN UPDATE SET *
                                WHEN NOT MATCHED AND source.operation != 'DELETE' THEN INSERT *""")
  
(spark.readStream
       .table("clients_cdc")
     .writeStream
       .foreachBatch(merge_stream)
       .option("checkpointLocation", raw_data_location+"/stream/checkpoint_clients_cdc")
       .trigger(processingTime='10 seconds')
       #.trigger(availableNow=True) --use this trigger on serverless
     .start())

time.sleep(20)

# %%
# %sql 
select * from retail_client_silver order by id asc;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>address</th><th>email</th><th>operation</th></tr></thead><tbody><tr><td>2</td><td>Updated_User_2</td><td>New_Address_619 Avenue</td><td>updated.user2@newcompany1.com</td><td>UPDATE</td></tr><tr><td>3</td><td>Updated_User_3</td><td>New_Address_330 Avenue</td><td>updated.user3@newcompany4.com</td><td>UPDATE</td></tr><tr><td>4</td><td>Updated_User_4</td><td>New_Address_280 Avenue</td><td>updated.user4@newcompany1.com</td><td>UPDATE</td></tr><tr><td>6</td><td>Updated_User_6</td><td>New_Address_915 Avenue</td><td>updated.user6@newcompany1.com</td><td>UPDATE</td></tr><tr><td>8</td><td>Updated_User_8</td><td>New_Address_877 Avenue</td><td>updated.user8@newcompany3.com</td><td>UPDATE</td></tr><tr><td>9</td><td>User_9_74</td><td>Address_270 Street</td><td>user9@company7.com</td><td>INSERT
in</td><td>quentin.ambard@databricks.com</td><td>Paris 75020</td><td>UPDATE</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2000</td><td>2025-01-10T18:08:15.019Z</td><td>null</td><td>null</td><td>null</td><td>DELETE</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1000</td><td>2025-01-10T18:28:03.13Z</td><td>Quentin</td><td>quentin.ambard@databricks.com</td><td>Paris 75020</td><td>UPDATE</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2000</td><td>2025-01-10T18:28:03.13Z</td><td>null</td><td>null</td><td>null</td><td>DELETE</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1000</td><td>2025-03-12T21:31:03.7Z</td><td>Quentin</td><td>quentin.ambard@databricks.com</td><td>Paris 75020</td><td>UPDATE</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2000</td><td>2025-03-12T21:31:03.7Z</td><td>null</td><td>null</td><td>null</td><td>DELETE</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1000</td><td>2025-05-13T21:16:21.173Z</td><td>Quentin</td><td>quentin.ambard@databricks.com</td><td>Paris 75020</td><td>UPDATE</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2000</td><td>2025-05-13T21:16:21.173Z</td><td>null</td><td>null</td><td>null</td><td>DELETE</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1000</td><td>2025-05-21T22:31:38.392853 ...

# %%
#wait for the stream to get the new data
time.sleep(20)

# %%
# %sql 
select * from retail_client_silver where id in (1000, 2000);
-- Note that ID 1000 has been updated, and ID 2000 is deleted
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>address</th><th>email</th><th>operation</th></tr></thead><tbody><tr><td>1000</td><td>Quentin</td><td>Paris 75020</td><td>quentin.ambard@databricks.com</td><td>UPDATE</td></tr></tbody></table></div>

# %% [markdown]
# ## Gold: capture and propagate Silver modifications downstream
#
# <img src="https://github.com/databricks-demos/dbdemos-resources/raw/main/images/product/Delta-Lake-CDC-CDF/cdc-flow-3.png" alt='Make all your data ready for BI and ML' style='float: right' width='600'/>
#
# We need to add a final Gold layer based on the data from the Silver table. If a row is DELETED or UPDATED in the SILVER layer, we want to apply the same modification in the GOLD layer.
#
# To do so, we need to capture all the tables changes from the SILVER layer and incrementally replicate the changes to the GOLD layer.
#
# This is very simple using Delta Lake CDF from our SILVER table!
#
# Delta Lake CDF provides the `table_changes('< table_name >', < delta_version >)` that you can use to select all the tables modifications from a specific Delta version to another one:

# %% [markdown]
# ### Working with Delta Lake CDF

# %%
# %sql
--Remember, CDC must be enabled in the silver table to capture the change. Let's make sure it's properly enabled:
ALTER TABLE retail_client_silver SET TBLPROPERTIES (delta.enableChangeDataFeed = true);

-- Delta Lake CDF works using table_changes function:
SELECT * FROM table_changes('retail_client_silver', 1)  order by id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>address</th><th>email</th><th>operation</th><th>_change_type</th><th>_commit_version</th><th>_commit_timestamp</th></tr></thead><tbody><tr><td>2</td><td>Updated_User_2</td><td>New_Address_619 Avenue</td><td>updated.user2@newcompany1.com</td><td>UPDATE</td><td>update_postimage</td><td>67</td><td>2025-09-23T13:57:51Z</td></tr><tr><td>2</td><td>User_2_76</td><td
-23T10:30:57Z</td></tr><tr><td>10</td><td>User_10_11</td><td>Address_479 Street</td><td>user10@company8.com</td><td>INSERT</td><td>insert</td><td>54</td><td>2025-09-23T10:30:57Z</td></tr><tr><td>10</td><td>User_10_11</td><td>Address_479 Street</td><td>user10@company8.com</td><td>INSERT</td><td>update_preimage</td><td>61</td><td>2025-09-23T13:30:20Z</td></tr><tr><td>10</td><td>User_10_59</td><td>Address_585 Street</td><td>user10@company1.com</td><td>INSERT</td><td>update_postimage</td><td>61</td><td>2025-09-23T13:30:20Z</td></tr> ...

# %% [markdown]
# #### Delta CDF table_changes output
# Table Changes provides back 4 cdc types in the "_change_type" column:
#
# | CDC Type             | Description                                                               |
# |----------------------|---------------------------------------------------------------------------|
# | **update_preimage**  | Content of the row before an update                                       |
# | **update_postimage** | Content of the row after the update (what you want to capture downstream) |
# | **delete**           | Content of a row that has been deleted                                    |
# | **insert**           | Content of a new row that has been inserted                               |
#
# Therefore, 1 update will result in 2 rows in the cdc stream (one row with the previous values, one with the new values)

# %%
from delta.tables import *

#Let's get the last table version to only see the last update mofications
last_version = str(DeltaTable.forName(spark, "retail_client_silver").history(1).head()["version"])
print(f"our Delta table last version is {last_version}, let's select the last changes to see our DELETE and UPDATE operations (last 2 versions):")

changes = spark.read.format("delta") \
                    .option("readChangeData", "true") \
                    .option("startingVersion", int(last_version) -1) \
                    .table("retail_client_silver")
display(changes)
# Out:
# our Delta table last version is 96, let's select the last changes to see our DELETE and UPDATE operations (last 2 versions):
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>address</th><th>email</th><th>operation</th><th>_change_type</th><th>_commit_version</th><th>_commit_timestamp</th></tr></thead><tbody><tr><td>1000</td><td>Quentin</td><td>Paris 75020</td><td>quentin.ambard@databricks.com</td><td>UPDATE</td><td>update_preimage</td><td>95</td><td>2025-10-21T19:01:54Z</td></tr><tr><td>1000</td><td>Quentin</td><td>Paris 75020</td><td>quentin.ambard@databricks.com</td><td>UPDATE</td><td>update_postimage</td><td>95</td><td>2025-10-21T19:01:54Z</td></tr></tbody></table></div>

# %% [markdown]
# ### Synchronizing our downstream GOLD table based from the Silver changes
#
# Let's now say that we want to perform another table enhancement and propagate these changes downstream.
#
# To keep this example simple, we'll just add a column name `gold_data` with random data, but in real world this could be an aggregation, a join with another datasource, an ML model etc.
#
# The same logic as the Silver layer must be implemented. Since we now consume the CDF data, we also need to perform a deduplication stage. Let's do it using the python APIs this time for the example.
#
# *Note: Streaming operations with CDC are supported from DBR 8.1+*

# %%
# %sql
CREATE TABLE IF NOT EXISTS retail_client_gold (id BIGINT NOT NULL, name STRING, address STRING, email STRING, gold_data STRING);

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import dense_rank, regexp_replace, lit, col

#Function to upsert `microBatchOutputDF` into Delta table using MERGE
def upsertToDelta(data, batchId):
  #First we need to deduplicate based on the id and take the most recent update
  windowSpec = Window.partitionBy("id").orderBy(col("_commit_version").desc())
  #Select only the first value 
  #getting the latest change is still needed if the cdc contains multiple time the same id. We can rank over the id and get the most recent _commit_version
  data_deduplicated = data.withColumn("rank", dense_rank().over(windowSpec)).where("rank = 1 and _change_type!='update_preimage'").drop("_commit_version", "rank")

  #Add some data cleaning for the gold layer to remove quotes from the address
  data_deduplicated = data_deduplicated.withColumn("address", regexp_replace(col("address"), "\"", ""))
  
  #run the merge in the gold table directly
  (DeltaTable.forName(spark, "retail_client_gold").alias("target")
      .merge(data_deduplicated.alias("source"), "source.id = target.id")
      .whenMatchedDelete("source._change_type = 'delete'")
      .whenMatchedUpdateAll("source._change_type != 'delete'")
      .whenNotMatchedInsertAll("source._change_type != 'delete'")
      .execute())


(spark.readStream
       .option("readChangeData", "true")
       .option("startingVersion", 1)
       .table("retail_client_silver")
       .withColumn("gold_data", lit("Delta CDF is Awesome"))
      .writeStream
        .foreachBatch(upsertToDelta)
        .option("checkpointLocation", raw_data_location+"/stream/checkpoint_clients_gold")
        .trigger(processingTime='10 seconds')
        #.trigger(availableNow=True) --use this trigger on serverless
      .start())

time.sleep(20)

# %%
# %sql SELECT * FROM retail_client_gold
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>address</th><th>email</th><th>gold_data</th></tr></thead><tbody><tr><td>407</td><td>Michelle</td><td>87694 Miller TrafficwayLake Mary, NM 70406</td><td>lleonard@sanders-collins.net</td><td>Delta CDF is Awesome</td></tr><tr><td>422</td><td>Jennifer</td><td>24120 Cantu Curve Apt. 811North Dylanport, AK 58318</td><td>qthomas@lopez-wilson.com</td><td>Delta CDF is Awesome</td></tr><tr><td>428</td><td>Paul</td><td>12059 Moreno VillagesDavilaborough, MO 08459</td><td>adam92@jackson-sullivan.org</td><td>Delta CDF is Awesome</td></tr><tr><td>429</td><td>Brandon</td><td>799 Hudson Village Apt. 242Scottshire, CO 41264</td><td>robinjohnson@mullins.net</td><td>Delta CDF is Awesome</td></tr><tr><td>430</td><td>Thomas</td><td>073 Conner Bridge Suite 165Hofurt, MP 28056</td><td>vwatkins@diaz-wise.com</td><td>Delta CDF is Awesome</td></tr><tr><td>431</td><td>Edward</td><td>19861 Rogers ForgesMatthewstad, MN 19754</td><td>ecox@bowen.biz</td><td>Delta CDF is Awesome</td></tr><tr><td>432</td><td>Antonio</td><td>5442 Richards ForgesEast Rachelview, NV 82553</td><td>estradasarah@goodman.com</td><td>Delta CDF is Awesome</td></tr><tr><td>434</td><td>Crystal</td><td>4659 Christopher Crest Apt. 641Meredithburgh, VT 62496</td><td>turnervanessa@garcia.com</td><td>Delta CDF is Awesome</td></tr><tr><td>439</td><td>Kimberly</td><td>082 Kathy Shoals Suite 852Ericfort, MO 22704</td><td>vasquezlisa@bailey.info</td><td>Delta CDF is Awesome</td></tr><tr><td>443</td><td>Tanner</td><td>5466 Ray Orchard Suite 327Dennisshire, HI 17435</td><td>jenna30@nielsen-baker.net</td><td>Delta CDF is Awesome</td></tr><tr><td>444</td><td>Cynthia</td><td>1510 Wendy Ports Suite 804Simmonsville, GA 34184</td><td>parkerdavid@thomas.com</td><td>Delta CDF is Awesome</td></tr><tr><td>448</td><td>Christy</td><td>9683 Miller Spur Suite 805Kimberlymouth, NJ 83584</td><td>osullivan@davis.info</td><td>Delta CDF is Awesome</td></tr><tr><td>453</td><td>Sabrina</td><td>63237 Evans EstateKennethfurt, MN 31770</td><td>elaine11@morris-murphy.com</td><td>Delta CDF is Awesome</td></tr><tr><td>454</td><td>Monique</td><td>USNS WarnerFPO AA 86637</td><td>lopezdebra@lopez.com</td><td>Delta CDF is Awesome</td></tr><tr><td>456</td><td>Lisa</td><td>USNS HoffmanFPO AE 48930</td><td>talvarado@brown.com</td><td>Delta CDF is Awesome</td></tr><tr><td>459</td><td>Jaime</td><td>USCGC MurphyFPO AE 11473</td><td>wpark@sims-lucas.biz</td><td>Delta CDF is Awesome</td></tr><tr><td>460</td><td>Kimberly</td><td>64315 Matthew NeckKelleybury, MO 09789</td><td>patricia22@miller.com</td><td>Delta CDF is Awesome</td></tr><tr><td>461</td><td>Sean</td><td>3033 Lynch ExpresswaySouth Katelynfurt, MO 23259</td><td>qbooth@rivera.com</td><td>Delta CDF is Awesome</td></tr><tr><td>493</td><td>Anthony</td><td>USCGC DelgadoFPO AA 39617</td><td>vunderwood@holt.com</td><td>Delta CDF is Awesome</td></tr><tr><td>494</td><td>Samantha</td><td>70764 Lee Landing Apt. 981Port Veronica, PR 40861</td><td>lisadavis@harris.com</td><td>Delta CDF is Awesome</td></tr><tr><td>497</td><td>Christian</td><td>22452 Theresa SpringsMartinmouth, VI 05782</td><td>boydcaitlin@ritter-marsh.com</td><td>Delta CDF is Awesome</td></tr><tr><td>509</td><td>Emily</td><td>70020 Taylor MewsPort Nicole, AZ 27310</td><td>hannahgibson@wong.com</td><td>Delta CDF is Awesome</td></tr><tr><td>512</td><td>Adrian</td><td>481 Roberson Street Apt. 508Phillipsfurt, OK 58386</td><td>santiagocrystal@harris.com</td><td>Delta CDF is Awesome</td></tr><tr><td>513</td><td>Mike</td><td>8830 Hall Gateway Suite 466Juantown, IA 18230</td><td>perrywilliam@williams.com</td><td>Delta CDF is Awesome</td></tr><tr><td>515</td><td>Cassidy</td><td>183 Roger ShoalsKristenberg, SC 86364</td><td>henryle@brown-reyes.com</td><td>Delta CDF is Awesome</td></tr><tr><td>517</td><td>Jacob</td><td>4830 Gray MillRonaldview, KY 71287</td><td>sstephenson@ellison-schneider.n ...

# %% [markdown]
# ### Support for data sharing and Datamesh organization
# <img src="https://github.com/databricks-demos/dbdemos-resources/raw/main/images/product/Delta-Lake-CDC-CDF/delta-cdf-datamesh.png" style="float:right; margin-right: 50px" width="300px" />
#
# As we've seen during this demo, you can track all the changes (INSERT/UPDATE/DELETE) from any Detlta table using the CDC option.
#
# It's then easy to subscribe the table modifications as an incremental process.
#
# This makes the Data Mesh implementation easy: each Mesh can publish a set of tables, and other meshes can subscribe the original changes.
#
# They are then in charge of propagating the changes (ex GDPR DELETE) to their own Data Mesh

# %% [markdown]
# ## Data is now ready for BI & ML use-case !
#
# <img src="https://github.com/databricks-demos/dbdemos-resources/raw/main/images/product/Delta-Lake-CDC-CDF/cdc-flow-4.png" alt='Make all your data ready for BI and ML' style='float: right' width='600'/>
#
# We now have our final table, updated based on the initial CDC information we receive.
#
# As next step, we can leverage Databricks Lakehouse platform to start creating SQL queries / dashboards or ML models

# %% [markdown]
# Next step: [Implement a CDC pipeline for multiple tables]($./02-CDC-CDF-full-multi-tables)

# %%
DBDemos.stop_all_streams()
# Out:
# Stopping 3 streams
# All stream stopped
