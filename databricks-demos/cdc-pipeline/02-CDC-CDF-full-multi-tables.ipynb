# %% [markdown]
# # Full demo: Change Data Capture on multiple tables
# ## Use-case: Synchronize all your ELT tables with your Lakehouse
#
# We previously saw how to synchronize a single table. However, real use-case typically includes multiple tables that we need to ingest and synch.
#
# These tables are stored on different folder having the following layout:
#
# <img width="1000px" src="https://github.com/databricks-demos/dbdemos-resources/raw/main/images/product/Delta-Lake-CDC-CDF/cdc-full.png">
#
# **A note on Spark Declarative Pipelines**:<br/>
# *Spark Declarative Pipelines has been designed to simplify this process and handle concurrent execution properly, without having you to start multiple stream in parallel.*<br/>
# *We strongly advise to have a look at the SDP CDC demo to simplify such pipeline implementation: `dbdemos.instal('dlt-cdc')`*
#
# In this notebook, we'll see how this can be done using Python & standard streaming APIs (without SDP).
#
# <!-- Collect usage data (view). Remove it to disable collection. View README for more details.  -->
# <img width="1px" src="https://ppxrzfxige.execute-api.us-west-2.amazonaws.com/v1/analytics?category=data-engineering&org_id=2162748966026566&notebook=%2F02-CDC-CDF-full-multi-tables&demo_name=cdc-pipeline&event=VIEW&path=%2F_dbdemos%2Fdata-engineering%2Fcdc-pipeline%2F02-CDC-CDF-full-multi-tables&version=1">

# %%
# %run ./_resources/00-setup $reset_all_data=false
# Out:
# USE CATALOG `main__build`
# using catalog.database `main__build`.`dbdemos_cdc_pipeline`
# data already existing. Run with reset_all_data=true to force a data cleanup for your local demo.

# %% [markdown]
# ## Running the streams in parallel
#
# Each table will be save as a distinct table, using a distinct Spark Structured Streaming strem.
#
# To implement an efficient pipeline, we should process multiple streams at the same time. To do that, we'll use a ThreadPoolExecutor and start multiple thread, each of them processing and waiting for a stream.
#
# We're using Trigger Once to refresh all the tables once and then shutdown the cluster, typically every hour. For lower latencies we can keep the streams running (depending of the number of tables & cluster size), or keep the Trigger Once but loop forever.
#
# *Note that for a real workload the exact number of streams depends of the total number of tables, table sizes and cluster size. We can also use several clusters to split the load if required*

# %% [markdown]
# ## Schema evolution
#
# By organizing the raw incoming cdc files with 1 folder by table, we can easily iterate over the folders and pickup any new tables without modification.
#
# Schema evolution will be handled my the Autoloader and Delta `mergeSchema` option at the bronze layer. Schema evolution for MERGE (Silver Layer) are supported using `spark.databricks.delta.schema.autoMerge.enabled`
#
# Using these options, we'll be able to capture new tables and table schema evolution without having to change our code.
#
# *Note: that autoloader will trigger an error in a stream if a schema change happens, and will automatically recover during the next run. See Autoloader demo for a complete example*
#
# *Note: another common pattern is to redirect all the CDC events to a single message queue (the table name being a message attribute), and then dispatch the message in different Silver Tables*

# %%
base_folder = f"{raw_data_location}/cdc"
display(dbutils.fs.ls(base_folder))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/main/dbdemos_cdc_pipeline/raw_data/cdc/transactions/</td><td>transactions/</td><td>0</td><td>1761073376885</td></tr><tr><td>dbfs:/Volumes/main/dbdemos_cdc_pipeline/raw_data/cdc/users/</td><td>users/</td><td>0</td><td>1761073376885</td></tr></tbody></table></div>

# %% [markdown]
# ## Silver and bronze transformations

# %%
dbutils.fs.rm(f"{raw_data_location}/cdc_full", True)
# Out:
# True

# %%
#Stream using the autoloader to ingest raw files and load them in a delta table
def update_bronze_layer(path, bronze_table):
  print(f"ingesting RAW cdc data for {bronze_table} and building bronze layer...")
  (spark.readStream
          .format("cloudFiles")
          .option("cloudFiles.format", "csv")
          .option("cloudFiles.schemaLocation", f"{raw_data_location}/cdc_full/schemas/{bronze_table}")
          .option("cloudFiles.schemaHints", "id bigint, operation_date timestamp")
          .option("cloudFiles.inferColumnTypes", "true")
          .load(path)
       .withColumn("file_name", col("_metadata.file_path"))
       .writeStream
          .option("checkpointLocation", f"{raw_data_location}/cdc_full/checkpoints/{bronze_table}")
          .option("mergeSchema", "true")
          #.trigger(processingTime='10 seconds')
          .trigger(availableNow=True)
          .table(bronze_table).awaitTermination())

# %%
#Stream incrementally loading new data from the bronze CDC table and merging them in the Silver table
def update_silver_layer(bronze_table, silver_table):
  print(f"ingesting {bronze_table} update and materializing silver layer using a MERGE statement...")
  #First create the silver table if it doesn't exists:
  if not spark.catalog.tableExists(silver_table):
    print(f"Table {silver_table} doesn't exist, creating it using the same schema as the bronze one...")
    spark.read.table(bronze_table).drop("operation", "operation_date", "_rescued_data", "file_name").write.saveAsTable(silver_table)

  #for each batch / incremental update from the raw cdc table, we'll run a MERGE on the silver table
  def merge_stream(updates, i):
    #First we need to deduplicate based on the id and take the most recent update
    windowSpec = Window.partitionBy("id").orderBy(col("operation_date").desc())
    #Select only the first value 
    #getting the latest change is still needed if the cdc contains multiple time the same id. We can rank over the id and get the most recent _commit_version
    updates_deduplicated = updates.withColumn("rank", row_number().over(windowSpec)).where("rank = 1").drop("operation_date", "_rescued_data", "file_name", "rank")
    #Remove the "operation" field from the column to update in the silver table (we don't want the technical "operation" field to appear here)
    columns_to_update = {c: f"updates.{c}"  for c in spark.read.table(silver_table).columns if c != "operation"}
    #run the merge in the silver table directly
    DeltaTable.forName(spark, silver_table).alias("target") \
        .merge(updates_deduplicated.alias("updates"), "updates.id = target.id") \
        .whenMatchedDelete("updates.operation = 'DELETE'") \
        .whenMatchedUpdate("updates.operation != 'DELETE'", set=columns_to_update) \
        .whenNotMatchedInsert("updates.operation != 'DELETE'", values=columns_to_update) \
        .execute()
    
  (spark.readStream
         .table(bronze_table)
       .writeStream
         .foreachBatch(merge_stream)
         .option("checkpointLocation", f"{raw_data_location}/cdc_full/checkpoints/{silver_table}")
          #.trigger(processingTime='10 seconds')
          .trigger(availableNow=True)
          .start().awaitTermination())

# %% [markdown]
# ## Starting all the streams
#
# We can now iterate over the folders to start the bronze & silver streams for each table.

# %%
from concurrent.futures import ThreadPoolExecutor
from collections import deque
from delta.tables import *
 
def refresh_cdc_table(table):
  try:
    #update the bronze table
    bronze_table = f'bronze_{table}'
    update_bronze_layer(f"{base_folder}/{table}", bronze_table)

    #then refresh the silver layer
    silver_table = f'silver_{table}'
    update_silver_layer(bronze_table, silver_table)
  except Exception as e:
    #prod workload should properly process errors
    print(f"couldn't properly process {bronze_table}")
    raise e
  
#Enable Schema evolution during merges (to capture new columns)  
#spark.conf.set("spark.databricks.delta.schema.autoMerge.enabled", "true")

#iterate over all the tables folders
tables = [table_path.name[:-1] for table_path in dbutils.fs.ls(base_folder)]
#Let's start 3 CDC flow at the same time in 3 different thread to speed up ingestion
with ThreadPoolExecutor(max_workers=3) as executor:
  deque(executor.map(refresh_cdc_table, tables))
  print(f"Database refreshed!")
# Out:
# ingesting RAW cdc data for bronze_transactions and building bronze layer...
# ingesting RAW cdc data for bronze_users and building bronze layer...
# ingesting bronze_transactions update and materializing silver layer using a MERGE statement...
# ingesting bronze_users update and materializing silver layer using a MERGE statement...
# Database refreshed!

# %%
# %sql select * from bronze_users
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>operation_date</th><th>name</th><th>email</th><th>address</th><th>operation</th><th>_rescued_data</th><th>file_name</th><th>username</th><th>status</th><th>processing_time</th></tr></thead><tbody><tr><td>0</td><td>2024-07-10T23:47:32.556Z</td><td>Megan</td><td>achang@green.info</td><td>48764 Howard Forge Apt. 421Vanessaside, VT 79393</td><td>APPEND</td><td>null</td><td>/Volumes/main/dbdemos_cdc_pipeline/raw_data/cdc/users/part-00000-tid-2391063570950057873-2925a499-74e1-4207-b7de-584e9f9e9c08-1000-1-c000.csv</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1</td><td>2024-07-10T23:47:32.556Z</td><td>Katherine</td><td>thull@howard-snow.com</td><td>PSC 4115, Box 7815APO AA 41945</td><td>APPEND</td><td>null</td><td>/Volumes/main/dbdemos_cdc_pipeline/raw_data/cdc/users/part-00000-tid-2391063570950057873-2925a499-74e1-4207-b7de-584e9f9e9c08-1000-1-c000.csv</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2</td><td>2024-07-10T23:47:32.556Z</td><td>Robert</td><td>juancampos@lloyd.org</td><td>778 Brown PlazaNorth Jenniferfurt, VT 88077</td><td>APPEND</td><td>null</td><td>/Volumes/main/dbdemos_cdc_pipeline/raw_data/cdc/users/part-00000-tid-2391063570950057873-2925a499-74e1-4207-b7de-584e9f9e9c08-1000-1-c000.csv</td><td>null</td><td>null</td><td>null</td></tr><tr><td>3</td><td>2024-07-10T23:47:32.556Z</td><td>Jonathan</td><td>kyleblair@rivera.com</td><td>3513 John Divide Suite 115Rodriguezside, LA 93111</td><td>APPEND</td><td>null</td><td>/Volumes/main/dbdemos_cdc_pipeline/raw_data/cdc/users/part-00000-tid-2391063570950057873-2925a499-74e1-4207-b7de-584e9f9e9c08-1000-1-c000.csv</td><td>null</td><td>null</td><td>null</td></tr><tr><td>4</td><td>2024-07-10T23:47:32.556Z</td><td>William</td><td>tammywoods@green.com</td><td>398 Wallace Ranch Suite 593Ivanburgh, AZ 80818</td><td>APPEND</td><td>null</td><td>/Volumes/main/dbdemos_cdc_pipeline/raw_data/cdc/users/part-00000-tid-2391063570950057873-2925a499-74e1-4207-b7de-584e9f9e9c08-1000-1-c000.csv</td><td>null</td><td>null</td><td>null</td></tr><tr><td>5</td><td>2024-07-10T23:47:32.556Z</td><td>Richard</td><td>cortezraymond@garrett.com</td><td>Unit 4711 Box 2201DPO AP 71358</td><td>APPEND</td><td>null</td><td>/Volumes/main/dbdemos_cdc_pipeline/raw_data/cdc/users/part-00000-tid-2391063570950057873-2925a499-74e1-4207-b7de-584e9f9e9c08-1000-1-c000.csv</td><td>null</td><td>null</td><td>null</td></tr><tr><td>6</td><td>2024-07-10T23:47:32.556Z</td><td>Kristen</td><td>jessicapadilla@lee.com</td><td>339 Riley Mission Suite 515South Brendamouth, PR 25454</td><td>APPEND</td><td>null</td><td>/Volumes/main/dbdemos_cdc_pipeline/raw_data/cdc/users/part-00000-tid-2391063570950057873-2925a499-74e1-4207-b7de-584e9f9e9c08-1000-1-c000.csv</td><td>null</td><td>null</td><td>null</td></tr><tr><td>7</td><td>2024-07-10T23:47:32.556Z</td><td>Kevin</td><td>lindathomas@west.net</td><td>35256 Craig Drive Apt. 098North Davidborough, PA 75992</td><td>APPEND</td><td>null</td><td>/Volumes/main/dbdemos_cdc_pipeline/raw_data/cdc/users/part-00000-tid-2391063570950057873-2925a499-74e1-4207-b7de-584e9f9e9c08-1000-1-c000.csv</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8</td><td>2024-07-10T23:47:32.556Z</td><td>Thomas</td><td>jrodriguez@mann-kelley.net</td><td>1090 Susan FerrySouth Jasonton, TX 03487</td><td>APPEND</td><td>null</td><td>/Volumes/main/dbdemos_cdc_pipeline/raw_data/cdc/users/part-00000-tid-2391063570950057873-2925a499-74e1-4207-b7de-584e9f9e9c08-1000-1-c000.csv</td><td>null</td><td>null</td><td>null</td></tr><tr><td>9</td><td>2024-07-10T23:47:32.556Z</td><td>Brandy</td><td>tamaramorrison@roberts.com</td><td>1314 Graham CircleWilliamsville, UT 51786</td><td>APPEND</td><td>null</td><td>/Volumes/main/dbdemos_cdc_pipeline/raw_data/cdc/users/part-00000-tid-2391063570950057873-2925a499-74e1-4207-b7de-584e9f9e9c08-1000-1-c000.csv</td><td>null</td><td>null</td><td>null</td>< ...

# %%
# %sql select * from silver_users
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>email</th><th>address</th></tr></thead><tbody><tr><td>19</td><td>updated_user_19</td><td>updated.user19@newcompany2.com</td><td>Updated_Address_216 Avenue</td></tr><tr><td>25</td><td>updated_user_25</td><td>updated.user25@newcompany5.com</td><td>Updated_Address_164 Avenue</td></tr><tr><td>26</td><td>user_26_3</td><td>user26@company3.com</td><td>Address_854 Street</td></tr><tr><td>29</td><td>updated_user_29</td><td>updated.user29@newcompany4.com</td><td>Updated_Address_480 Avenue</td></tr><tr><td>31</td><td>updated_user_31</td><td>updated.user31@newcompany4.com</td><td>Updated_Address_560 Avenue</td></tr><tr><td>39</td><td>updated_user_39</td><td>updated.user39@newcompany5.com</td><td>Updated_Address_694 Avenue</td></tr><tr><td>43</td><td>user_43_26</td><td>user43@company6.com</td><td>Address_119 Street</td></tr><tr><td>50</td><td>updated_user_50</td><td>updated.user50@newcompany1.com</td><td>Updated_Address_501 Avenue</td></tr><tr><td>57</td><td>updated_user_57</td><td>updated.user57@newcompany2.com</td><td>Updated_Address_564 Avenue</td></tr><tr><td>65</td><td>user_65_17</td><td>user65@company2.com</td><td>Address_323 Street</td></tr><tr><td>84</td><td>user_84_91</td><td>user84@company9.com</td><td>Address_563 Street</td></tr><tr><td>94</td><td>user_94_53</td><td>user94@company10.com</td><td>Address_48 Street</td></tr><tr><td>110</td><td>user_110_37</td><td>user110@company8.com</td><td>Address_4 Street</td></tr><tr><td>112</td><td>updated_user_112</td><td>updated.user112@newcompany4.com</td><td>Updated_Address_24 Avenue</td></tr><tr><td>116</td><td>user_116_30</td><td>user116@company6.com</td><td>Address_108 Street</td></tr><tr><td>119</td><td>user_119_66</td><td>user119@company6.com</td><td>Address_980 Street</td></tr><tr><td>126</td><td>updated_user_126</td><td>updated.user126@newcompany4.com</td><td>Updated_Address_815 Avenue</td></tr><tr><td>144</td><td>updated_user_144</td><td>updated.user144@newcompany4.com</td><td>Updated_Address_249 Avenue</td></tr><tr><td>145</td><td>user_145_53</td><td>user145@company6.com</td><td>Address_857 Street</td></tr><tr><td>155</td><td>user_155_48</td><td>user155@company7.com</td><td>Address_708 Street</td></tr><tr><td>190</td><td>updated_user_190</td><td>updated.user190@newcompany1.com</td><td>Updated_Address_234 Avenue</td></tr><tr><td>198</td><td>user_198_25</td><td>user198@company9.com</td><td>Address_625 Street</td></tr><tr><td>203</td><td>user_203_18</td><td>user203@company5.com</td><td>Address_113 Street</td></tr><tr><td>212</td><td>updated_user_212</td><td>updated.user212@newcompany4.com</td><td>Updated_Address_909 Avenue</td></tr><tr><td>232</td><td>updated_user_232</td><td>updated.user232@newcompany2.com</td><td>Updated_Address_147 Avenue</td></tr><tr><td>237</td><td>user_237_52</td><td>user237@company1.com</td><td>Address_222 Street</td></tr><tr><td>262</td><td>updated_user_262</td><td>updated.user262@newcompany4.com</td><td>Updated_Address_858 Avenue</td></tr><tr><td>264</td><td>user_264_45</td><td>user264@company4.com</td><td>Address_701 Street</td></tr><tr><td>274</td><td>updated_user_274</td><td>updated.user274@newcompany1.com</td><td>Updated_Address_873 Avenue</td></tr><tr><td>278</td><td>updated_user_278</td><td>updated.user278@newcompany4.com</td><td>Updated_Address_213 Avenue</td></tr><tr><td>296</td><td>updated_user_296</td><td>updated.user296@newcompany4.com</td><td>Updated_Address_414 Avenue</td></tr><tr><td>299</td><td>updated_user_299</td><td>updated.user299@newcompany1.com</td><td>Updated_Address_256 Avenue</td></tr><tr><td>325</td><td>updated_user_325</td><td>updated.user325@newcompany5.com</td><td>Updated_Address_309 Avenue</td></tr><tr><td>326</td><td>updated_user_326</td><td>updated.user326@newcompany4.com</td><td>Updated_Address_660 Avenue</td></tr><tr><td>347</td><td>updated_user_347</td><td>updated.user347@newcompany4. ...

# %%
# %sql select * from silver_transactions
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>item_count</th><th>amount</th></tr></thead><tbody><tr><td>0</td><td>1</td><td>180</td></tr><tr><td>1</td><td>3</td><td>815</td></tr><tr><td>2</td><td>2</td><td>587</td></tr><tr><td>3</td><td>3</td><td>957</td></tr><tr><td>4</td><td>1</td><td>219</td></tr><tr><td>5</td><td>2</td><td>376</td></tr><tr><td>6</td><td>3</td><td>817</td></tr><tr><td>7</td><td>3</td><td>723</td></tr><tr><td>8</td><td>3</td><td>729</td></tr><tr><td>9</td><td>1</td><td>323</td></tr><tr><td>10</td><td>3</td><td>816</td></tr><tr><td>11</td><td>1</td><td>118</td></tr><tr><td>12</td><td>2</td><td>346</td></tr><tr><td>13</td><td>3</td><td>823</td></tr><tr><td>14</td><td>2</td><td>486</td></tr><tr><td>15</td><td>2</td><td>534</td></tr><tr><td>16</td><td>3</td><td>980</td></tr><tr><td>17</td><td>2</td><td>633</td></tr><tr><td>18</td><td>2</td><td>518</td></tr><tr><td>19</td><td>2</td><td>556</td></tr><tr><td>20</td><td>1</td><td>24</td></tr><tr><td>21</td><td>2</td><td>638</td></tr><tr><td>22</td><td>1</td><td>32</td></tr><tr><td>23</td><td>3</td><td>741</td></tr><tr><td>24</td><td>3</td><td>692</td></tr><tr><td>25</td><td>1</td><td>108</td></tr><tr><td>26</td><td>1</td><td>76</td></tr><tr><td>27</td><td>2</td><td>517</td></tr><tr><td>28</td><td>1</td><td>204</td></tr><tr><td>29</td><td>3</td><td>729</td></tr><tr><td>30</td><td>2</td><td>440</td></tr><tr><td>31</td><td>2</td><td>670</td></tr><tr><td>32</td><td>3</td><td>1008</td></tr><tr><td>33</td><td>3</td><td>709</td></tr><tr><td>34</td><td>2</td><td>372</td></tr><tr><td>35</td><td>3</td><td>992</td></tr><tr><td>36</td><td>2</td><td>580</td></tr><tr><td>37</td><td>2</td><td>613</td></tr><tr><td>38</td><td>3</td><td>923</td></tr><tr><td>39</td><td>3</td><td>925</td></tr><tr><td>40</td><td>2</td><td>570</td></tr><tr><td>41</td><td>2</td><td>513</td></tr><tr><td>42</td><td>1</td><td>48</td></tr><tr><td>43</td><td>1</td><td>169</td></tr><tr><td>44</td><td>1</td><td>94</td></tr><tr><td>45</td><td>3</td><td>702</td></tr><tr><td>46</td><td>1</td><td>292</td></tr><tr><td>47</td><td>1</td><td>60</td></tr><tr><td>48</td><td>2</td><td>621</td></tr><tr><td>49</td><td>2</td><td>536</td></tr><tr><td>50</td><td>2</td><td>561</td></tr><tr><td>51</td><td>1</td><td>74</td></tr><tr><td>52</td><td>3</td><td>830</td></tr><tr><td>53</td><td>3</td><td>870</td></tr><tr><td>54</td><td>1</td><td>282</td></tr><tr><td>55</td><td>3</td><td>920</td></tr><tr><td>56</td><td>3</td><td>894</td></tr><tr><td>57</td><td>1</td><td>99</td></tr><tr><td>58</td><td>2</td><td>662</td></tr><tr><td>59</td><td>1</td><td>247</td></tr><tr><td>60</td><td>2</td><td>545</td></tr><tr><td>61</td><td>1</td><td>131</td></tr><tr><td>62</td><td>2</td><td>587</td></tr><tr><td>63</td><td>3</td><td>819</td></tr><tr><td>64</td><td>3</td><td>786</td></tr><tr><td>65</td><td>3</td><td>730</td></tr><tr><td>66</td><td>3</td><td>941</td></tr><tr><td>67</td><td>1</td><td>42</td></tr><tr><td>68</td><td>3</td><td>930</td></tr><tr><td>69</td><td>3</td><td>846</td></tr><tr><td>70</td><td>1</td><td>208</td></tr><tr><td>71</td><td>3</td><td>930</td></tr><tr><td>72</td><td>1</td><td>330</td></tr><tr><td>73</td><td>2</td><td>494</td></tr><tr><td>74</td><td>2</td><td>551</td></tr><tr><td>75</td><td>2</td><td>392</td></tr><tr><td>76</td><td>1</td><td>277</td></tr><tr><td>77</td><td>3</td><td>854</td></tr><tr><td>78</td><td>1</td><td>331</td></tr><tr><td>79</td><td>1</td><td>330</td></tr><tr><td>80</td><td>3</td><td>945</td></tr><tr><td>81</td><td>1</td><td>69</td></tr><tr><td>82</td><td>2</td><td>484</td></tr><tr><td>83</td><td>3</td><td>782</td></tr><tr><td>84</td><td>2</td><td>446</td></tr><tr><td>85</td><td>3</td><td>897</td></tr><tr><td>86</td><td>2</td><td>675</td></tr><tr><td>87</td><td>1</td><td>293</td></tr><tr><td>88</td><td>3</td><td>876</td></tr><tr><td>89</td><td>3</td><td>742</td></tr><tr><td>90</td><td>2</td><td>628</td></tr><tr><td>91</td><t ...

# %% [markdown]
# ## What's next
#
# All our silver tables are now materialized using the CDC events! We can then work extra transformation (gold layer) based on your business requirement.
#
# ### Production readiness
# Error and exception in each stream should be properly captured. Multiple strategy exist: send a notification when a table has some error and continue processing the others, stop the entire job, define table "priorities" etc.
#
# ### Spark Declarative Pipelines
# To simplify these operations & error handling, we strongly advise you to run your CDC pipelines on top of Spark Declarative Pipelines: `dbdemos.install('pipeline-bike')`

# %%
DBDemos.stop_all_streams()
