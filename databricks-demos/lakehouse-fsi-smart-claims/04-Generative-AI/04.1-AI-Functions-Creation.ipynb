# %% [markdown]
# # 🔍 From Manual Reviews to AI-Powered Claims Summaries & Fraud Detection
#
# ---
#
# The financial services industry faces mounting pressure to improve claims processing efficiency while combating fraud. Manual claim summarization processes lead to inconsistent documentation, delayed fraud detection, and inefficient archival of suspicious cases—resulting in operational bottlenecks and increased financial exposure.
#
# <div style="background: #f7f7f7; border-left: 5px solid #ff5f46; padding: 20px; margin: 20px 0; font-size: 18px;">
# "Industry benchmarks reveal <b>30-day average resolution times</b> for complex claims, with manual processes accounting for <b>40% of processing time</b>—far exceeding the <b>7-10 day ideal</b> for high-risk cases requiring detailed documentation."[^1]
# </div>
#
# <div style="background: #f7f7f7; border-left: 5px solid green; padding: 20px; margin: 20px 0; font-size: 18px;">
# "Generative AI reduces claims processing time by <b>50%</b> through automated summarization while improving fraud detection accuracy by <b>35%</b> through pattern recognition in historical data."[^2]
# </div>
#
# <img src="https://raw.githubusercontent.com/databricks-demos/dbdemos-resources/refs/heads/main/images/liza.png" style="width: 100px; vertical-align: middle; margin-right: 10px; float: left;" />
# <br>
# Liza, a Generative AI Engineer, is implementing Databricks AI to transform claims management. Her system will:
# <div style="background: #e0f7fa; border-left: 5px solid #00796b; padding-left: 10px; margin: 0 0; margin-left: 120px">
#   <ol style="text-align: left;">
#     <li>Retrieve all information pertaining to a certain claim id</li>
#     <li>Automate structured claim summaries using GenAI</li>
#     <li>Archive enriched case files to Unity Catalog for auditor review</li>
#   </ol>
# </div>
#
# <!-- [^1]: MD Clarity Industry Benchmark Report 2024, Shipping Insurance Processing Metrics
# [^2]: Ricoh USA Claims Automation Study 2023, Ziffity AI Implementation Case Studies
# [^3]: Convin AI Fraud Detection Whitepaper 2024: Anomaly Detection in Financial Documents -->
#
# <!-- Collect usage data (view). Remove it to disable collection or disable tracker during installation. View README for more details.  -->
# <img width="1px" src="https://ppxrzfxige.execute-api.us-west-2.amazonaws.com/v1/analytics?category=lakehouse&org_id=2162748966026566&notebook=%2F04-Generative-AI%2F04.1-AI-Functions-Creation&demo_name=lakehouse-fsi-smart-claims&event=VIEW&path=%2F_dbdemos%2Flakehouse%2Flakehouse-fsi-smart-claims%2F04-Generative-AI%2F04.1-AI-Functions-Creation&version=1">

# %% [markdown]
# ## The Demo: Automate Suspicious Claims Summaries with Databricks GenAI
# <!--
# <img src="https://raw.githubusercontent.com/databricks-demos/dbdemos-resources/refs/heads/main/images/retail/lakehouse-churn/lakehouse-retail-c360-agent-functions.png"
#      style="float: right; margin-top: 10px; width: 700px; display: block;" /> -->
#
# Databricks Generative AI is revolutionizing claims processing by enabling organizations to automate manual workflows, detect fraud, and unlock insights from previously siloed claims data. Where traditional claims processing can be a time-intensive endeavor, Databricks allows
#
# In this demo, we showcase a practical use case for Databricks to improve claims management. We will create an AI agent using the following functions, defined in the subsequent cells:
#
# 1. **Claims Data Retriever**: This function allows our GenAI agent to fetch claims data based on a given `claim_id`, pulling structured and unstructured data from our Databricks Lakehouse.
# 2. **Claims Summary Generator**: Using generative AI models, this function generates concise summaries of claims, including key details such as incident descriptions, policyholder information, and flagged anomalies for further review.
#
# Finally, we will demonstrate how these functions can be applied in batch processing to unlock insights from archived claims data. By automating claims summarization and enabling real-time access to enriched data, insurers can improve operational efficiency and expedite fraud detection.
#
# By leveraging Generative AI, insurers can move beyond manual processes to actively **streamline workflows, reduce costs, and enhance fraud detection capabilities**.

# %%
# %run ../_resources/00-setup $reset_all_data=false
# Out:
# run done
# USE CATALOG `main__build`
# using catalog.database `main__build`.`dbdemos_fsi_smart_claims`
# data already existing.

# %% [markdown]
# ## 📊 Function 1: Get Claim Details
#
# <div style="display: flex; align-items: center; gap: 15px;">
#   <img src="https://raw.githubusercontent.com/databricks-demos/dbdemos-resources/refs/heads/main/images/liza.png"
#        style="width: 100px; border-radius: 10px;" />
#   <div>
#     Liza's first step in automating claims processing is to retrieve all relevant information for a given claim.
#     This function, `get_claim_details`, takes in a claim ID and returns the necessary data to generate a comprehensive claim summary.
#     The retrieved data includes incident descriptions, policyholder information, claim history, and any associated documents—providing the foundation for accurate and efficient summarization.
#   </div>
# </div>
#
# ### 🛠️ Next Step
# In the following section, we define the `get_claim_details` function, which retrieves structured and unstructured data from the Databricks Lakehouse to enable automated claims summarization.

# %%
# %sql
CREATE OR REPLACE FUNCTION get_claim_details (
  claim_id STRING
)
RETURNS TABLE (
  claim_no STRING,
  policy_no STRING,
  chassis_number STRING,
  claim_amount_total BIGINT,
  incident_type STRING,
  incident_date DATE,
  incident_severity STRING,
  driver_age DOUBLE,
  suspicious_activity BOOLEAN,
  make STRING,
  model STRING,
  model_year BIGINT,
  policytype STRING,
  sum_insured DOUBLE,
  borough STRING,
  neighborhood STRING
)
LANGUAGE SQL
COMMENT 'Returns essential claim details for the given claim ID'
RETURN(
  SELECT
    claim_no,
    policy_no,
    CHASSIS_NO AS chassis_number,
    claim_amount_total,
    incident_type,
    incident_date,
    incident_severity,
    driver_age,
    suspicious_activity,
    MAKE as make,
    MODEL as model,
    MODEL_YEAR as model_year,
    POLICYTYPE as policytype,
    SUM_INSURED as sum_insured,
    BOROUGH as borough,
    NEIGHBORHOOD as neighborhood
  FROM claim_policy_telematics
  WHERE claim_no = claim_id
  LIMIT 1);

# %% [markdown]
# ### Example:
#
# Let's ensure that our new tool works. Here we look up a claim that we know is suspicious for testing:

# %%
# %sql
SELECT * FROM get_claim_details("5627e63a-f54b-4316-8abe-a5c5c3cfc7e0")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>claim_no</th><th>policy_no</th><th>chassis_number</th><th>claim_amount_total</th><th>incident_type</th><th>incident_date</th><th>incident_severity</th><th>driver_age</th><th>suspicious_activity</th><th>make</th><th>model</th><th>model_year</th><th>policytype</th><th>sum_insured</th><th>borough</th><th>neighborhood</th></tr></thead><tbody><tr><td>5627e63a-f54b-4316-8abe-a5c5c3cfc7e0</td><td>102085057</td><td>JN1CC11C37T012187</td><td>61500</td><td>Single Vehicle Collision</td><td>2016-04-20</td><td>Minor Damage</td><td>47.0</td><td>true</td><td>NISSAN</td><td>TIIDA</td><td>2007</td><td>COMP</td><td>10000.0</td><td>QUEENS</td><td>WEST CENTRAL QUEENS</td></tr></tbody></table></div>

# %% [markdown]
# ### Example:
#
# And, let's look up a claim we know is not suspicious!

# %%
# %sql
SELECT * FROM get_claim_details("553b6891-37cb-406b-9b59-e97d4e47b8e1")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>claim_no</th><th>policy_no</th><th>chassis_number</th><th>claim_amount_total</th><th>incident_type</th><th>incident_date</th><th>incident_severity</th><th>driver_age</th><th>suspicious_activity</th><th>make</th><th>model</th><th>model_year</th><th>policytype</th><th>sum_insured</th><th>borough</th><th>neighborhood</th></tr></thead><tbody><tr><td>553b6891-37cb-406b-9b59-e97d4e47b8e1</td><td>102107383</td><td>WBAHT1102H5H73209</td><td>51570</td><td>Parked Car</td><td>2018-07-15</td><td>Major Damage</td><td>38.0</td><td>false</td><td>BMW</td><td>X1</td><td>2017</td><td>COMP</td><td>170000.0</td><td>QUEENS</td><td>SOUTHEAST QUEENS</td></tr></tbody></table></div>

# %% [markdown]
# ## 📝 Function 2: Generate Claim Summary
#
# <div style="display: flex; align-items: center; gap: 15px;">
#   <img src="https://raw.githubusercontent.com/databricks-demos/dbdemos-resources/refs/heads/main/images/liza.png"
#        style="width: 100px; border-radius: 10px;" />
#   <div>
#     After retrieving the necessary claim details using the `get_claim_details` function, the next step is to generate a concise and structured summary of the claim.
#     The `generate_claim_summary` function uses Generative AI to process the retrieved data and produce a human-readable summary, which includes:
#     <ul>
#       <li>Incident description</li>
#       <li>Policyholder information</li>
#       <li>Claim amount and status</li>
#       <li>Relevant notes or flagged items for further review</li>
#     </ul>
#     This summary helps streamline claims processing and provides a clear overview for auditors or claims adjusters.
#   </div>
# </div>
#
# ### 🛠️ Next Step
# In the following section, we define the `generate_claim_summary` function, which takes the output from `get_claim_details` and applies Generative AI to create structured summaries for individual claims. This enables faster decision-making and improved efficiency in claims management workflows.

# %% [markdown]
# ### Step 1: Define the model prompt
#
# This function will utilize Perplexity by-default for creating customized claims summaries.
#
# Feel free to manipulate and change the below prompt in order to generate whatever kind of claims summary you think would be most impactful!

# %%
prompt = """
You are an expert insurance claim analyst with 25 years of experience in the auto insurance industry. Your task is to generate a comprehensive, professional claim summary report.

## Output Format:
Create a well-structured report with these clearly labeled sections:
1. **CLAIM SUMMARY**: A concise 3-4 sentence overview of the incident
2. **CLAIM INFORMATION**: Policy details and financial impact
3. **INCIDENT DETAILS**: Date, location, type, and severity
4. **VEHICLE INFORMATION**: Make, model, and specifications
5. **RISK ASSESSMENT**: Analysis of any suspicious activity and next steps

## Guidelines:
- Maintain professional, formal language suitable for insurance industry standards
- Be precise with facts, dates, and monetary values
- If suspicious activity is flagged, note potential investigation requirements
- The tone should be objective and authoritative
- Total report length should be approximately 250-300 words
- Format monetary values appropriately (e.g., $10,000.00)
- Use insurance industry terminology where appropriate

Analyze the following claim data and provide your expert assessment:
"""

# %% [markdown]
# ### Step 2: Function definition
#
# Next, like before, we will utilize `ai_query` to define our function, leveraging the prompt from our previous cell as well as the previous two functions.

# %%
spark.sql(f"""
  CREATE OR REPLACE FUNCTION generate_claim_summary(
    claim_no STRING,
    policy_no STRING,
    chassis_number STRING,
    claim_amount_total STRING,
    incident_type STRING,
    incident_date STRING,
    incident_severity STRING,
    driver_age STRING,
    suspicious_activity STRING,
    make STRING,
    model STRING,
    model_year STRING,
    policytype STRING,
    sum_insured STRING,
    borough STRING,
    neighborhood STRING
  )
  RETURNS STRING
  LANGUAGE SQL
  COMMENT "Generates a professional insurance claim summary using AI based on the provided claim details. This function produces a well-structured report with sections for Claim Information, Incident Details, Vehicle Information, and Policy Details."
  RETURN (
    SELECT ai_query(
      'databricks-meta-llama-3-1-405b-instruct',
      CONCAT(
        "{prompt}"
        'Claim details: ', 
        TO_JSON(NAMED_STRUCT('claim_no', claim_no, 'policy_no', policy_no, 'chassis_number', chassis_number, 'claim_amount_total', claim_amount_total, 'incident_type', incident_type, 'incident_date', incident_date, 'incident_severity', incident_severity, 'driver_age', driver_age, 'suspicious_activity', suspicious_activity, 'make', make, 'model', model, 'model_year', model_year, 'policytype', policytype, 'sum_insured', sum_insured, 'borough', borough, 'neighborhood', neighborhood))
      )
    )
  )
  """)
# Out:
# DataFrame[]

# %% [markdown]
# ###  Step 3a: Suspicious Claim Example:
# Now, let's make sure that this works. Let's manually input claims data pertaining to a claim we know is suspicious, and see how the summary looks! Feel free to modify the prompt above if you prefer a different output!

# %%
# %sql
SELECT generate_claim_summary("5627e63a-f54b-4316-8abe-a5c5c3cfc7e0", "102085057", "JN1CC11C37T012187", "61500", "Single Vehicle Collision", "2016-04-20", "Minor Damage", "47", "true", "NISSAN", "TIIDA", "2007", "COMP", "10000", "QUEENS", "WEST CENTRAL QUEENS") AS claim_summary
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>claim_summary</th></tr></thead><tbody><tr><td>**CLAIM SUMMARY**
#
# This report summarizes a single vehicle collision claim, policy number 102085057, involving a 2007 Nissan Tiida with minor damage sustained on April 20, 2016. The claimant, a 47-year-old driver, has submitted a claim for $61,500.00. Initial assessment indicates potential suspicious activity, which may warrant further investigation.
#
# **CLAIM INFORMATION**
#
# - Policy Number: 102085057
# - Policy Type: Comprehensive (COMP)
# - Sum Insured: $10,000.00
# - Claim Amount Total: $61,500.00
# - Claim Number: 5627e63a-f54b-4316-8abe-a5c5c3cfc7e0
#
# **INCIDENT DETAILS**
#
# - Incident Date: April 20, 2016
# - Incident Type: Single Vehicle Collision
# - Incident Severity: Minor Damage
# - Location: West Central Queens, Queens Borough
#
# **VEHICLE INFORMATION**
#
# - Vehicle Make: Nissan
# - Vehicle Model: Tiida
# - Model Year: 2007
# - Chassis Number: JN1CC11C37T012187
#
# **RISK ASSESSMENT**
#
# Given the discrepancy between the claim amount ($61,500.00) and the sum insured ($10,000.00), along with the flagged suspicious activity, a detailed investigation is recommended. The minor damage severity does not appear to justify the substantial claim amount, suggesting potential fraud or error in the claim submission. Further analysis, including inspection of the vehicle and verification of the incident details, is necessary to determine the legitimacy of the claim and to assess the appropriate course of action.</td></tr></tbody></table></div>

# %% [markdown]
# ###  Step 3b: Non-Suspicious Claim Example:
# Now, let's make sure that this works. Let's manually input claims data pertaining to a claim we know is suspicious, and see how the summary looks! Feel free to modify the prompt above if you prefer a different output!

# %%
# %sql
SELECT generate_claim_summary("553b6891-37cb-406b-9b59-e97d4e47b8e1",	"102107383",	"WBAHT1102H5H73209",	"51570",	"Parked Car",	"2018-07-15",	"Major Damage",	"38",	"false",	"BMW", "X1",	"2017",	"COMP",	"170000",	"QUEENS",	"SOUTHEAST QUEENS") AS claim_summary
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>claim_summary</th></tr></thead><tbody><tr><td>**CLAIM SUMMARY**
#
# This report summarizes a claim submitted for a 2017 BMW X1 that sustained major damage while parked on July 15, 2018, in Southeast Queens. The claimant is requesting a total of $51,570.00 in compensation. Our analysis will examine the claim's validity, assess potential risks, and determine the next steps in the claims process.
#
# **CLAIM INFORMATION**
#
# - **Policy Number:** 102107383
# - **Policy Type:** Comprehensive (COMP)
# - **Sum Insured:** $170,000.00
# - **Claim Amount Total:** $51,570.00
#
# **INCIDENT DETAILS**
#
# - **Date of Incident:** July 15, 2018
# - **Location of Incident:** Southeast Queens
# - **Type of Incident:** Parked Car
# - **Incident Severity:** Major Damage
#
# **VEHICLE INFORMATION**
#
# - **Make:** BMW
# - **Model:** X1
# - **Model Year:** 2017
# - **Chassis Number:** WBAHT1102H5H73209
#
# **RISK ASSESSMENT**
#
# Based on the information provided, there are no immediate indicators of suspicious activity. However, as with all claims of this nature, a thorough investigation is recommended to verify the circumstances surrounding the incident, assess the extent of the damage, and confirm that the claim amount is reasonable and in line with the policy's terms and conditions. This may involve inspecting the vehicle, reviewing any available surveillance footage, and interviewing the claimant and any witnesses. The outcome of this investigation will determine the legitimacy of the claim and guide the decision on whether to approve the requested compensation of $51,570.00.</td></tr></tbody></table></div>

# %% [markdown]
# ## 🚀 Operation 3: Apply Our Functions in Batch to Suspicious Claims
#
# <div style="display: flex; align-items: center; gap: 15px;">
#   <img src="https://raw.githubusercontent.com/databricks-demos/dbdemos-resources/refs/heads/main/images/liza.png"
#        style="width: 100px; border-radius: 10px;" />
#   <div>
#     Now that Liza has implemented the `get_claim_details` and `generate_claim_summary` functions, the next step is to scale these operations by applying them in batch to a dataset of suspicious claims.
#     This operation enables organizations to:
#     <ul>
#       <li>Process large volumes of archived claims efficiently</li>
#       <li>Generate summaries for flagged claims based on predefined criteria (e.g., high claim amounts or anomalies)</li>
#       <li>Democratize access to enriched claim data for auditors and fraud investigators</li>
#       <li>Identify patterns across multiple claims for fraud detection and risk analysis</li>
#     </ul>
#     By leveraging Databricks' scalable compute capabilities, this batch processing operation ensures that even large datasets can be analyzed quickly and effectively.
#   </div>
# </div>
#
# ### 🛠️ Next Step
# In the following section, we demonstrate how to apply the `get_claim_details` and `generate_claim_summary` functions in batch mode to process suspicious claims. This includes:
# 1. Loading a dataset of flagged claims from Unity Catalog.
# 2. Iteratively applying the functions to generate summaries for each claim.
# 3. Storing the enriched summaries back into Unity Catalog for downstream analysis.
#
# <small>💡 Batch processing unlocks insights from historical claims data, enabling proactive fraud detection and improved operational efficiency.</small>

# %% [markdown]
# <div style="background: #ffe6e6; border-left: 5px solid #ff5f46; padding: 15px; margin: 20px 0; font-size: 16px;">
# 🚨 <b>Notice:</b> Uncomment the following block of code to generate claim summaries in batch!
#
#
# ⚠️ <i>Note:</i> This operation may take some time depending on the size of your dataset and the size of Databricks compute that you utilize.
# </div>

# %%
# %sql
CREATE OR REPLACE TABLE suspicious_claim_report_table AS
SELECT 
  claim_no, 
  suspicious_activity, 
  generate_claim_summary(
    claim_no, 
    policy_no, 
    CHASSIS_NO, 
    claim_amount_total, 
    incident_type, 
    incident_date, 
    incident_severity, 
    driver_age, 
    suspicious_activity, 
    MAKE, 
    MODEL, 
    MODEL_YEAR, 
    POLICYTYPE, 
    SUM_INSURED, 
    BOROUGH, 
    NEIGHBORHOOD
  ) AS claim_report 
FROM (
  SELECT * 
  FROM claim_policy_telematics
  WHERE suspicious_activity = true
  -- REMOVE LIMIT if you would like to apply this summarization to more claims!
  LIMIT 5
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT * FROM suspicious_claim_report_table LIMIT 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>claim_no</th><th>suspicious_activity</th><th>claim_report</th></tr></thead><tbody><tr><td>18f1495a-9a02-46d8-8968-897ac1514523</td><td>true</td><td>**CLAIM SUMMARY**
#
# This report summarizes a claim submitted for a 2019 AUDI A3, which was allegedly stolen on January 31, 2020, in the Greenwich Village and Soho neighborhood of Manhattan. The claimant is seeking compensation for the total loss of the vehicle, with a claimed amount of $50,700.00. Our analysis will examine the claim details, incident specifics, vehicle information, and assess potential risks.
#
# **CLAIM INFORMATION**
#
# - Policy Number: 102147937
# - Claim Number: 18f1495a-9a02-46d8-8968-897ac1514523
# - Policy Type: Comprehensive (COMP)
# - Sum Insured: $88,000.00
# - Claim Amount Total: $50,700.00
#
# **INCIDENT DETAILS**
#
# - Incident Type: Vehicle Theft
# - Incident Date: January 31, 2020
# - Incident Severity: Major Damage
# - Location: Greenwich Village and Soho, Manhattan
#
# **VEHICLE INFORMATION**
#
# - Make: AUDI
# - Model: A3
# - Model Year: 2019
# - Chassis Number: WAUZZZFF4K1002499
#
# **RISK ASSESSMENT**
#
# Given the claimant's age (26) and the nature of the incident (vehicle theft), along with the flag for suspicious activity, a thorough investigation is warranted. This should include verification of the theft with local law enforcement, review of any available surveillance footage, and an interview with the claimant to clarify the circumstances surrounding the incident. The claimed amount of $50,700.00 is below the sum insured of $88,000.00, but the incident's facts and the presence of suspicious activity necessitate a cautious approach to ensure the legitimacy of the claim. Further investigation will determine the appropriate course of action for claim resolution.</td></tr><tr><td>354f257a-837e-47d8-bd7f-01a4c63618e2</td><td>true</td><td>**CLAIM SUMMARY**
#
# This report summarizes a claim filed under policy number 102147963, involving a 2016 Mercedes C200 that sustained minor damage while parked on August 4, 2020, in the North Queens neighborhood of Queens borough. The total claim amount is $74,400.00. The incident has raised flags for suspicious activity, warranting further investigation.
#
# **CLAIM INFORMATION**
#
# - Policy Number: 102147963
# - Policy Type: Comprehensive (COMP)
# - Sum Insured: $99,000.00
# - Claim Amount Total: $74,400.00
#
# **INCIDENT DETAILS**
#
# - Incident Date: August 4, 2020
# - Incident Type: Parked Car
# - Incident Severity: Minor Damage
# - Location: North Queens, Queens Borough
#
# **VEHICLE INFORMATION**
#
# - Make: Mercedes
# - Model: C200
# - Model Year: 2016
# - Chassis Number: WDDWF4CB7GR131936
#
# **RISK ASSESSMENT**
#
# Given the nature of the incident and the fact that suspicious activity has been flagged, it is recommended that this claim undergo a thorough investigation. The minor damage sustained by the vehicle in a parked state, combined with the high claim amount of $74,400.00, raises questions about the circumstances surrounding the incident. An investigation will help determine the legitimacy of the claim and ensure that the compensation requested is appropriate and in line with policy terms. This may involve inspecting the vehicle, reviewing any available surveillance footage, and interviewing the claimant and potential witnesses.</td></tr><tr><td>58fedd4f-14c8-4fb0-9204-fec7a3440dfb</td><td>true</td><td>**CLAIM SUMMARY**
#
# This report summarizes a single vehicle collision claim, policy number 102147966, involving a 2020 KIA RIO with minor damage sustained on May 10, 2020, in North Queens, Queens. The total claim amount is $5,400.00. Suspicious activity has been flagged, requiring further investigation.
#
# **CLAIM INFORMATION**
#
# - Policy Number: 102147966
# - Policy Type: Comprehensive (COMP)
# - Sum Insured: $78,625.00
# - Claim Number: 58fedd4f-14c8-4fb0-9204-fec7a3440dfb
# - Total Claim Amount: $5,400.00
#
# **INCIDENT DETAILS**
#
# - Incident Date: May 10, 2020
# - Incident Type: Single Vehicle Collision
# - Incident Severity: Minor Damage
# - Location: North Queens, Queens
#
# **VEHICLE INFORMATION**
#
# - Vehicle Make: KIA
# - Vehicle Model: RIO
# - Model Year: 2020
# - Chassis Number: 3KPA351CXLE254831
#
# **RISK ASSESSMENT**
#
# Given the flag for suspicious activity, it is recommended that this claim undergo a thorough investigation to verify the legitimacy of the incident and the extent of the damages claimed. The investigation should include an assessment of the vehicle's condition, review of any available surveillance footage, and interviews with the driver and any witnesses. The driver's age (21) and the nature of the incident (single vehicle collision with minor damage) should also be considered during the investigation to determine if there are any indicators of potential fraud or if the incident was preventable. Further analysis will be necessary to make a determination on the claim's validity and the appropriate course of action.</td></tr><tr><td>fae9ff44-9d67-4960-9c6a-d20af5c5cec0</td><td>true</td><td>**CLAIM SUMMARY**
#
# This report summarizes a claim submitted for a 2019 Nissan Sunny involved in a multi-vehicle collision on August 7, 2020, in West Central Queens, resulting in a total loss. The claimant, a 42-year-old driver, is requesting a total of $6,600.00 in compensation. Our analysis raises concerns regarding potential suspicious activity, which may necessitate further investigation.
#
# **CLAIM INFORMATION**
#
# - Policy Number: 102147986
# - Policy Type: Comprehensive (COMP)
# - Sum Insured: $31,450.00
# - Claim Amount Total: $6,600.00
#
# **INCIDENT DETAILS**
#
# - Incident Date: August 7, 2020
# - Incident Type: Multi-vehicle Collision
# - Incident Severity: Total Loss
# - Location: West Central Queens
#
# **VEHICLE INFORMATION**
#
# - Make: Nissan
# - Model: Sunny
# - Model Year: 2019
# - Chassis Number: MDHBN7AD3KG679227
#
# **RISK ASSESSMENT**
#
# Given the indication of suspicious activity, it is recommended that this claim undergo a thorough investigation to verify the legitimacy of the claim and the circumstances surrounding the incident. This may include reviewing police reports, interviewing witnesses, and assessing the vehicle's damage in relation to the reported incident. The outcome of this investigation will determine the next steps in processing the claim.</td></tr><tr><td>3ffc5a4f-05d4-4842-bc44-0ad4f5acb88b</td><td>true</td><td>**CLAIM SUMMARY**
#
# This report summarizes a comprehensive analysis of claim #3ffc5a4f-05d4-4842-bc44-0ad4f5acb88b, involving a 2018 Honda Civic that sustained a total loss while parked. The incident occurred on November 27, 2020, in the West Queens neighborhood of Queens, NY. The claimant, a 23-year-old driver, has submitted a claim for $58,500.00.
#
# **CLAIM INFORMATION**
#
# * Policy Number: 102148008
# * Policy Type: Comprehensive (COMP)
# * Sum Insured: $55,546.00
# * Claim Amount Total: $58,500.00
#
# **INCIDENT DETAILS**
#
# * Incident Date: November 27, 2020
# * Incident Type: Parked Car
# * Incident Severity: Total Loss
# * Location: West Queens, Queens, NY
#
# **VEHICLE INFORMATION**
#
# * Make: Honda
# * Model: Civic
# * Model Year: 2018
# * Chassis Number: 19XFC1691JE450052
#
# **RISK ASSESSMENT**
#
# Our analysis has flagged this claim for suspicious activity, which may require further investigation. The claim amount exceeds the sum insured, and the incident type (parked car) raises questions about the circumstances surrounding the loss. We recommend a thorough examination of the vehicle and the claimant's account of events to verify the legitimacy of the claim. Potential next steps include requesting additional documentation, conducting an inspection of the vehicle, and/or interviewing the claimant to gather more information.</td></tr></tbody></table></div>

# %% [markdown]
# ## Next Steps
#
# Proceed to notebook [04.2-Agent-Creation-Guide]($./04.2-Agent-Creation-Guide) in order to package the above functions into an implementable AI Agent with Databricks!
