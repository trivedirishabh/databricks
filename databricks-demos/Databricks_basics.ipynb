# %%
# %sql
CREATE CATALOG IF NOT EXISTS trivris;

# %%
# %sql
USE CATALOG trivris;
CREATE SCHEMA IF NOT EXISTS learning;

# %%
# %sql

CREATE OR REPLACE TABLE learning.bronze (id INT, name STRING, age INT);

# %%
# %sql
DROP TABLE learning.bronze;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS learning.volume

# %%
# %sql
CREATE TABLE learning.bronze AS 
    SELECT * FROM read_files('/Volumes/trivris/learning/volume/employees.csv', format=>'csv', header=>'true')

# %%
# %sql
SELECT * FROM learning.bronze;

# %%
# %pip install dbdemos

# %%
import dbdemos

dbdemos.list_demos()
