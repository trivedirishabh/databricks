-- %% [markdown]
-- ### Example Exploratory Notebook
--
-- Use this notebook to explore the data generated by the pipeline in your preferred programming language.
--
-- **Note**: This notebook is not executed as part of the pipeline.

-- %%
--Explore raw historical turbine status data

SELECT * FROM json.`/Volumes/main/dbdemos_iot_platform/turbine_raw_landing/historical_turbine_status`
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>abnormal_sensor</th><th>end_time</th><th>maintenance_report</th><th>start_time</th><th>turbine_id</th></tr></thead><tbody><tr><td>ok</td><td>1708019819</td><td>null</td><td>1705423928</td><td>80b65386-569c-8036-01a5-ba50ad38835e</td></tr><tr><td>ok</td><td>1708017744</td><td>null</td><td>1705423976</td><td>e2fc885b-b2c2-aa23-0bce-46bdc23facbc</td></tr><tr><td>sensor_F</td><td>1708019967</td><td>
-- Issue: Gear tooth damage
-- Root Cause: Misalignment, overload, or improper lubrication of gearbox components, leading to excessive wear and fatigue on gear teeth.
-- ...

-- %%
--Explore raw sensor data
SELECT * FROM parquet.`/Volumes/main/dbdemos_iot_platform/turbine_raw_landing/incoming_data`

-- %%
--Explore raw turbine data

SELECT * FROM json.`/Volumes/main/dbdemos_iot_platform/turbine_raw_landing/turbine`
