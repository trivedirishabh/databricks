# %% [markdown]
# ### Example Exploratory Notebook
#
# Use this notebook to explore the data generated by the pipeline in your preferred programming language.
#
# **Note**: This notebook is not executed as part of the pipeline.

# %%
#Explore raw historical turbine status data

sdf = spark.read.format("json").load("/Volumes/main/dbdemos_iot_platform/turbine_raw_landing/historical_turbine_status")
display(sdf)

# %%
#Explore raw sensor data
sdf = spark.read.format("parquet").load("/Volumes/main/dbdemos_iot_platform/turbine_raw_landing/incoming_data")
display(sdf)

# %%
#Explore raw turbine data

sdf = spark.read.format("json").load("/Volumes/main/dbdemos_iot_platform/turbine_raw_landing/turbine")
display(sdf)
